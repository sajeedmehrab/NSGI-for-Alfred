# %%
from pathlib import Path 
import json
import os 
from tqdm import tqdm
import random
import copy

# %%
alfred_dir = Path('/home/ksmehrab/EmbAIProject/data/json_2.1.0')
train_data_dir = alfred_dir / 'train'

# %%
task_dirs = os.listdir(train_data_dir)

# %%
task_dirs
# Out:
# ['pick_and_place_with_movable_recep-DishSponge-Pan-DiningTable-20',
#  'look_at_obj_in_light-BaseballBat-None-DeskLamp-316',
#  'pick_and_place_simple-Knife-None-SinkBasin-28',
#  'pick_cool_then_place_in_recep-BreadSliced-None-Microwave-24',
#  'pick_clean_then_place_in_recep-Fork-None-Drawer-8',
#  'pick_and_place_with_movable_recep-Vase-Box-DiningTable-227',
#  'pick_heat_then_place_in_recep-Apple-None-SinkBasin-19',
#  'pick_cool_then_place_in_recep-Pan-None-CounterTop-12',
#  'look_at_obj_in_light-Laptop-None-DeskLamp-216',
#  'pick_and_place_with_movable_recep-Watch-Bowl-SideTable-326',
#  'pick_and_place_simple-Kettle-None-Cabinet-18',
#  'pick_cool_then_place_in_recep-BreadSliced-None-GarbageCan-30',
#  'pick_and_place_with_movable_recep-KeyChain-Plate-CoffeeTable-228',
#  'pick_cool_then_place_in_recep-Bowl-None-Cabinet-25',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-GarbageCan-6',
#  'pick_two_obj_and_place-Candle-None-Toilet-419',
#  'pick_two_obj_and_place-BreadSliced-None-Fridge-14',
#  'pick_cool_then_place_in_recep-Potato-None-Microwave-18',
#  'pick_clean_then_place_in_recep-Knife-None-DiningTable-15',
#  'look_at_obj_in_light-Book-None-DeskLamp-328',
#  'pick_clean_then_place_in_recep-Pan-None-Fridge-13',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-DiningTable-18',
#  'pick_cool_then_place_in_recep-Bread-None-DiningTable-16',
#  'pick_and_place_simple-Cloth-None-SinkBasin-417',
#  'pick_and_place_with_movable_recep-Pencil-Bowl-Desk-305',
#  'pick_and_place_simple-WateringCan-None-Desk-204',
#  'pick_clean_then_place_in_recep-Cloth-None-Drawer-415',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-Fridge-15',
#  'look_at_obj_in_light-Vase-None-FloorLamp-204',
#  'pick_clean_then_place_in_recep-SoapBar-None-Toilet-408',
#  'pick_clean_then_place_in_recep-Spoon-None-DiningTable-21',
#  'pick_clean_then_place_in_recep-SoapBar-None-Cabinet-402',
#  'pick_two_obj_and_place-AlarmClock-None-SideTable-312',
#  'pick_two_obj_and_place-Glassbottle-None-Fridge-1',
#  'pick_clean_then_place_in_recep-Kettle-None-StoveBurner-18',
#  'pick_cool_then_place_in_recep-Pot-None-StoveBurner-25',
#  'pick_and_place_simple-BasketBall-None-Desk-312',
#  'pick_two_obj_and_place-ToiletPaper-None-Drawer-423',
#  'pick_and_place_simple-TomatoSliced-None-SideTable-3',
#  'pick_two_obj_and_place-Potato-None-Fridge-25',
#  'pick_and_place_simple-CreditCard-None-ArmChair-201',
#  'pick_clean_then_place_in_recep-Tomato-None-SideTable-3',
#  'pick_heat_then_place_in_recep-Egg-None-DiningTable-19',
#  'pick_and_place_simple-Statue-None-Dresser-319',
#  'pick_and_place_with_movable_recep-AppleSliced-Pot-DiningTable-4',
#  'pick_clean_then_place_in_recep-Mug-None-CoffeeMachine-14',
#  'pick_and_place_with_movable_recep-Spoon-Pan-SinkBasin-4',
#  'pick_two_obj_and_place-SaltShaker-None-Cabinet-21',
#  'pick_clean_then_place_in_recep-Ladle-None-CounterTop-14',
#  'pick_and_place_with_movable_recep-Apple-Pot-CounterTop-4',
#  'pick_clean_then_place_in_recep-Cloth-None-Toilet-413',
#  'pick_and_place_with_movable_recep-AppleSliced-Bowl-Fridge-26',
#  'pick_clean_then_place_in_recep-Cloth-None-Toilet-405',
#  'pick_two_obj_and_place-RemoteControl-None-ArmChair-207',
#  'pick_clean_then_place_in_recep-Spatula-None-Drawer-8',
#  'pick_heat_then_place_in_recep-Potato-None-Fridge-19',
#  'pick_clean_then_place_in_recep-Lettuce-None-CounterTop-18',
#  'pick_and_place_with_movable_recep-Pencil-Bowl-SideTable-316',
#  'pick_and_place_simple-Cloth-None-Drawer-409',
#  'pick_and_place_with_movable_recep-Fork-Mug-SinkBasin-11',
#  'pick_two_obj_and_place-KeyChain-None-SideTable-322',
#  'pick_heat_then_place_in_recep-Potato-None-Fridge-6',
#  'pick_clean_then_place_in_recep-Spatula-None-DiningTable-24',
#  'pick_and_place_with_movable_recep-TomatoSliced-Pan-Fridge-16',
#  'pick_two_obj_and_place-Pen-None-SideTable-330',
#  'pick_two_obj_and_place-SprayBottle-None-GarbageCan-420',
#  'pick_two_obj_and_place-Vase-None-CoffeeTable-209',
#  'pick_and_place_with_movable_recep-ButterKnife-Plate-SinkBasin-5',
#  'pick_and_place_with_movable_recep-PotatoSliced-Pan-DiningTable-27',
#  'pick_two_obj_and_place-Pencil-None-Shelf-301',
#  'look_at_obj_in_light-Box-None-DeskLamp-225',
#  'pick_and_place_simple-HandTowel-None-Toilet-427',
#  'pick_and_place_simple-Pillow-None-Sofa-209',
#  'pick_two_obj_and_place-RemoteControl-None-CoffeeTable-207',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-CounterTop-8',
#  'pick_and_place_with_movable_recep-ButterKnife-Plate-CounterTop-13',
#  'pick_and_place_simple-Spoon-None-SinkBasin-19',
#  'pick_and_place_with_movable_recep-Knife-Pot-DiningTable-23',
#  'pick_cool_then_place_in_recep-TomatoSliced-None-CounterTop-14',
#  'pick_two_obj_and_place-RemoteControl-None-CoffeeTable-227',
#  'look_at_obj_in_light-BaseballBat-None-DeskLamp-305',
#  'pick_two_obj_and_place-PepperShaker-None-Shelf-20',
#  'pick_and_place_simple-Pen-None-Desk-310',
#  'pick_and_place_simple-BasketBall-None-Dresser-314',
#  'pick_and_place_simple-LettuceSliced-None-DiningTable-24',
#  'pick_two_obj_and_place-CellPhone-None-Safe-302',
#  'pick_and_place_with_movable_recep-ButterKnife-Mug-SideTable-21',
#  'pick_and_place_simple-WineBottle-None-DiningTable-15',
#  'look_at_obj_in_light-RemoteControl-None-FloorLamp-220',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-203',
#  'pick_cool_then_place_in_recep-Lettuce-None-CounterTop-22',
#  'pick_and_place_simple-Pencil-None-SideTable-309',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-206',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-DiningTable-23',
#  'pick_and_place_with_movable_recep-LettuceSliced-Pot-DiningTable-21',
#  'look_at_obj_in_light-TissueBox-None-DeskLamp-225',
#  'pick_and_place_with_movable_recep-Watch-Plate-SideTable-201',
#  'pick_and_place_with_movable_recep-Knife-Pan-CounterTop-17',
#  'pick_heat_then_place_in_recep-Plate-None-CounterTop-7',
#  'pick_and_place_simple-Glassbottle-None-DiningTable-23',
#  'pick_clean_then_place_in_recep-ButterKnife-None-DiningTable-27',
#  'pick_and_place_simple-PotatoSliced-None-SinkBasin-25',
#  'pick_and_place_simple-RemoteControl-None-ArmChair-222',
#  'pick_and_place_with_movable_recep-Spoon-Pan-SinkBasin-20',
#  'pick_two_obj_and_place-TissueBox-None-Shelf-313',
#  'pick_two_obj_and_place-HandTowel-None-Toilet-418',
#  'pick_two_obj_and_place-CreditCard-None-ArmChair-311',
#  'pick_two_obj_and_place-SoapBottle-None-Toilet-403',
#  'pick_two_obj_and_place-Pen-None-SideTable-329',
#  'look_at_obj_in_light-Book-None-DeskLamp-317',
#  'pick_and_place_with_movable_recep-ButterKnife-Cup-CounterTop-23',
#  'pick_cool_then_place_in_recep-Pan-None-DiningTable-7',
#  'pick_and_place_with_movable_recep-Spatula-Pot-DiningTable-23',
#  'pick_heat_then_place_in_recep-Mug-None-Shelf-5',
#  'pick_heat_then_place_in_recep-Cup-None-Fridge-13',
#  'pick_heat_then_place_in_recep-BreadSliced-None-CounterTop-13',
#  'pick_and_place_simple-SprayBottle-None-Toilet-412',
#  'pick_and_place_with_movable_recep-TomatoSliced-Plate-Fridge-23',
#  'pick_cool_then_place_in_recep-Egg-None-Microwave-5',
#  'pick_heat_then_place_in_recep-Egg-None-Fridge-13',
#  'pick_and_place_simple-KeyChain-None-ArmChair-214',
#  'pick_and_place_with_movable_recep-KeyChain-Box-ArmChair-225',
#  'look_at_obj_in_light-Bowl-None-DeskLamp-304',
#  'pick_cool_then_place_in_recep-Lettuce-None-SinkBasin-13',
#  'pick_two_obj_and_place-KeyChain-None-Drawer-307',
#  'pick_and_place_simple-CreditCard-None-Shelf-307',
#  'pick_heat_then_place_in_recep-AppleSliced-None-SinkBasin-14',
#  'pick_two_obj_and_place-Pan-None-CounterTop-14',
#  'pick_two_obj_and_place-RemoteControl-None-Sofa-201',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-SinkBasin-4',
#  'pick_and_place_simple-Vase-None-CoffeeTable-206',
#  'pick_two_obj_and_place-Pencil-None-Drawer-327',
#  'pick_heat_then_place_in_recep-Tomato-None-Fridge-12',
#  'pick_two_obj_and_place-Bowl-None-CoffeeTable-203',
#  'pick_and_place_simple-CellPhone-None-Safe-323',
#  'pick_clean_then_place_in_recep-Kettle-None-DiningTable-15',
#  'pick_clean_then_place_in_recep-Pan-None-CounterTop-22',
#  'pick_and_place_with_movable_recep-PotatoSliced-Pan-Fridge-6',
#  'pick_and_place_with_movable_recep-Fork-Mug-CounterTop-26',
#  'pick_and_place_simple-Pillow-None-Ottoman-208',
#  'pick_heat_then_place_in_recep-Tomato-None-SinkBasin-11',
#  'pick_cool_then_place_in_recep-WineBottle-None-GarbageCan-17',
#  'look_at_obj_in_light-Vase-None-FloorLamp-221',
#  'pick_cool_then_place_in_recep-Lettuce-None-CounterTop-11',
#  'pick_and_place_with_movable_recep-Pen-Mug-Dresser-324',
#  'pick_clean_then_place_in_recep-LettuceSliced-None-Fridge-12',
#  'pick_and_place_simple-CreditCard-None-Sofa-220',
#  'pick_clean_then_place_in_recep-Cup-None-Shelf-1',
#  'look_at_obj_in_light-Bowl-None-DeskLamp-323',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-220',
#  'pick_and_place_simple-Book-None-Desk-313',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-317',
#  'pick_two_obj_and_place-CellPhone-None-Sofa-224',
#  'pick_and_place_simple-Watch-None-SideTable-222',
#  'look_at_obj_in_light-Statue-None-DeskLamp-304',
#  'pick_two_obj_and_place-Pen-None-Dresser-327',
#  'pick_and_place_with_movable_recep-TomatoSliced-Plate-Microwave-1',
#  'pick_and_place_simple-AlarmClock-None-Desk-314',
#  'pick_clean_then_place_in_recep-DishSponge-None-BathtubBasin-414',
#  'pick_and_place_simple-CellPhone-None-ArmChair-318',
#  'pick_cool_then_place_in_recep-Mug-None-Shelf-5',
#  'pick_clean_then_place_in_recep-Fork-None-DiningTable-24',
#  'pick_cool_then_place_in_recep-WineBottle-None-DiningTable-17',
#  'pick_cool_then_place_in_recep-Lettuce-None-CounterTop-25',
#  'pick_and_place_with_movable_recep-Spoon-Mug-CounterTop-16',
#  'pick_two_obj_and_place-SoapBar-None-BathtubBasin-405',
#  'pick_cool_then_place_in_recep-Mug-None-Cabinet-22',
#  'pick_two_obj_and_place-Newspaper-None-ArmChair-230',
#  'pick_and_place_with_movable_recep-Spoon-Mug-SinkBasin-5',
#  'pick_and_place_simple-SprayBottle-None-Toilet-426',
#  'pick_heat_then_place_in_recep-Mug-None-SideTable-21',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-GarbageCan-12',
#  'pick_heat_then_place_in_recep-Egg-None-Fridge-20',
#  'pick_cool_then_place_in_recep-Bowl-None-Cabinet-2',
#  'pick_cool_then_place_in_recep-Mug-None-Shelf-1',
#  'look_at_obj_in_light-Statue-None-FloorLamp-223',
#  'pick_clean_then_place_in_recep-Cloth-None-Dresser-415',
#  'pick_and_place_with_movable_recep-Pen-Bowl-Dresser-327',
#  'pick_two_obj_and_place-Egg-None-Microwave-30',
#  'pick_clean_then_place_in_recep-AppleSliced-None-SideTable-21',
#  'pick_two_obj_and_place-CreditCard-None-ArmChair-214',
#  'pick_and_place_simple-SprayBottle-None-GarbageCan-409',
#  'look_at_obj_in_light-Bowl-None-DeskLamp-327',
#  'pick_two_obj_and_place-SoapBar-None-GarbageCan-420',
#  'pick_clean_then_place_in_recep-LettuceSliced-None-DiningTable-27',
#  'pick_clean_then_place_in_recep-DishSponge-None-Shelf-401',
#  'pick_heat_then_place_in_recep-AppleSliced-None-Fridge-16',
#  'pick_cool_then_place_in_recep-Tomato-None-Microwave-5',
#  'pick_cool_then_place_in_recep-TomatoSliced-None-SinkBasin-4',
#  'pick_clean_then_place_in_recep-Ladle-None-Cabinet-20',
#  'pick_and_place_with_movable_recep-LettuceSliced-Pan-Fridge-27',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-GarbageCan-24',
#  'pick_and_place_simple-Candle-None-Toilet-405',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-CounterTop-2',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-CounterTop-1',
#  'pick_clean_then_place_in_recep-Pan-None-Cabinet-1',
#  'pick_and_place_with_movable_recep-CellPhone-Bowl-Dresser-305',
#  'pick_and_place_with_movable_recep-RemoteControl-Box-CoffeeTable-222',
#  'pick_clean_then_place_in_recep-Kettle-None-DiningTable-7',
#  'pick_cool_then_place_in_recep-Plate-None-Cabinet-4',
#  'pick_heat_then_place_in_recep-Egg-None-Fridge-4',
#  'look_at_obj_in_light-Laptop-None-DeskLamp-301',
#  'look_at_obj_in_light-RemoteControl-None-FloorLamp-229',
#  'pick_two_obj_and_place-ToiletPaper-None-CounterTop-406',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-223',
#  'pick_clean_then_place_in_recep-Pot-None-StoveBurner-4',
#  'pick_and_place_with_movable_recep-LettuceSliced-Pot-CounterTop-17',
#  'pick_two_obj_and_place-CD-None-Safe-302',
#  'pick_and_place_with_movable_recep-LettuceSliced-Pan-Fridge-25',
#  'pick_clean_then_place_in_recep-TomatoSliced-None-CounterTop-25',
#  'pick_heat_then_place_in_recep-BreadSliced-None-Fridge-17',
#  'pick_and_place_simple-Watch-None-CoffeeTable-222',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-1',
#  'pick_two_obj_and_place-SoapBar-None-Cart-430',
#  'pick_and_place_with_movable_recep-Knife-Mug-DiningTable-11',
#  'pick_two_obj_and_place-Newspaper-None-ArmChair-222',
#  'pick_two_obj_and_place-Candle-None-CounterTop-406',
#  'pick_heat_then_place_in_recep-Tomato-None-CounterTop-26',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-SideTable-28',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-225',
#  'pick_and_place_with_movable_recep-Fork-Cup-SinkBasin-30',
#  'pick_and_place_with_movable_recep-CellPhone-Plate-SideTable-211',
#  'look_at_obj_in_light-AlarmClock-None-DeskLamp-304',
#  'look_at_obj_in_light-Pencil-None-DeskLamp-303',
#  'pick_cool_then_place_in_recep-Potato-None-GarbageCan-18',
#  'pick_and_place_simple-DishSponge-None-Toilet-403',
#  'pick_two_obj_and_place-Newspaper-None-CoffeeTable-211',
#  'pick_and_place_simple-Box-None-ArmChair-217',
#  'pick_cool_then_place_in_recep-Mug-None-CoffeeMachine-26',
#  'pick_two_obj_and_place-Pencil-None-SideTable-329',
#  'pick_clean_then_place_in_recep-Mug-None-CoffeeMachine-22',
#  'pick_clean_then_place_in_recep-AppleSliced-None-GarbageCan-6',
#  'pick_and_place_simple-KeyChain-None-Ottoman-203',
#  'pick_heat_then_place_in_recep-Egg-None-Fridge-19',
#  'pick_and_place_simple-HandTowel-None-BathtubBasin-422',
#  'pick_and_place_with_movable_recep-Spoon-Bowl-DiningTable-4',
#  'pick_and_place_simple-Tomato-None-Microwave-13',
#  'pick_clean_then_place_in_recep-Cloth-None-BathtubBasin-403',
#  'pick_and_place_simple-Pillow-None-ArmChair-225',
#  'pick_two_obj_and_place-SprayBottle-None-Dresser-413',
#  'pick_heat_then_place_in_recep-Potato-None-DiningTable-20',
#  'pick_cool_then_place_in_recep-Cup-None-DiningTable-24',
#  'pick_two_obj_and_place-HandTowel-None-SinkBasin-427',
#  'pick_clean_then_place_in_recep-Fork-None-CounterTop-23',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-12',
#  'pick_clean_then_place_in_recep-Cup-None-Microwave-1',
#  'pick_clean_then_place_in_recep-Spoon-None-Drawer-24',
#  'pick_two_obj_and_place-SprayBottle-None-Toilet-417',
#  'pick_clean_then_place_in_recep-AppleSliced-None-Microwave-6',
#  'look_at_obj_in_light-Book-None-DeskLamp-304',
#  'pick_cool_then_place_in_recep-AppleSliced-None-GarbageCan-25',
#  'pick_two_obj_and_place-ToiletPaper-None-Toilet-405',
#  'pick_and_place_with_movable_recep-ButterKnife-Pan-CounterTop-18',
#  'pick_two_obj_and_place-CreditCard-None-ArmChair-222',
#  'pick_two_obj_and_place-CreditCard-None-ArmChair-221',
#  'pick_two_obj_and_place-CellPhone-None-Dresser-229',
#  'pick_and_place_simple-Candle-None-Cart-401',
#  'pick_and_place_with_movable_recep-Watch-Box-DiningTable-228',
#  'pick_cool_then_place_in_recep-Bowl-None-Microwave-25',
#  'look_at_obj_in_light-Laptop-None-FloorLamp-211',
#  'pick_and_place_with_movable_recep-Statue-Box-CoffeeTable-204',
#  'pick_heat_then_place_in_recep-Egg-None-GarbageCan-2',
#  'pick_two_obj_and_place-LettuceSliced-None-Fridge-1',
#  'pick_and_place_with_movable_recep-Fork-Cup-DiningTable-23',
#  'pick_and_place_with_movable_recep-Spoon-Pot-DiningTable-21',
#  'pick_and_place_with_movable_recep-Spatula-Pan-DiningTable-28',
#  'pick_clean_then_place_in_recep-PotatoSliced-None-CounterTop-24',
#  'pick_cool_then_place_in_recep-Pan-None-StoveBurner-26',
#  'pick_heat_then_place_in_recep-Plate-None-Cabinet-7',
#  'pick_cool_then_place_in_recep-Lettuce-None-DiningTable-21',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-28',
#  'pick_and_place_with_movable_recep-Fork-Pan-SinkBasin-13',
#  'pick_and_place_with_movable_recep-Fork-Cup-CounterTop-26',
#  'pick_and_place_with_movable_recep-TomatoSliced-Pan-Fridge-11',
#  'pick_heat_then_place_in_recep-Apple-None-SinkBasin-17',
#  'pick_and_place_with_movable_recep-Pencil-Bowl-CoffeeTable-201',
#  'pick_cool_then_place_in_recep-BreadSliced-None-GarbageCan-19',
#  'pick_cool_then_place_in_recep-Bowl-None-DiningTable-4',
#  'look_at_obj_in_light-Laptop-None-DeskLamp-317',
#  'pick_clean_then_place_in_recep-Kettle-None-StoveBurner-30',
#  'pick_cool_then_place_in_recep-Potato-None-Microwave-15',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-23',
#  'pick_two_obj_and_place-Pillow-None-ArmChair-321',
#  'pick_and_place_simple-SprayBottle-None-Cabinet-413',
#  'pick_clean_then_place_in_recep-DishSponge-None-Cart-430',
#  'pick_cool_then_place_in_recep-WineBottle-None-DiningTable-16',
#  'pick_heat_then_place_in_recep-BreadSliced-None-GarbageCan-2',
#  'pick_clean_then_place_in_recep-Egg-None-DiningTable-23',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-203',
#  'look_at_obj_in_light-Mug-None-DeskLamp-323',
#  'pick_two_obj_and_place-ButterKnife-None-SinkBasin-22',
#  'look_at_obj_in_light-CellPhone-None-FloorLamp-224',
#  'look_at_obj_in_light-Newspaper-None-FloorLamp-212',
#  'pick_and_place_with_movable_recep-ButterKnife-Cup-DiningTable-23',
#  'pick_heat_then_place_in_recep-Tomato-None-Fridge-25',
#  'look_at_obj_in_light-Pencil-None-DeskLamp-306',
#  'pick_clean_then_place_in_recep-Ladle-None-Cabinet-8',
#  'pick_and_place_with_movable_recep-CellPhone-Box-SideTable-224',
#  'pick_and_place_simple-SprayBottle-None-Drawer-423',
#  'look_at_obj_in_light-Book-None-DeskLamp-305',
#  'pick_two_obj_and_place-RemoteControl-None-CoffeeTable-222',
#  'pick_clean_then_place_in_recep-ButterKnife-None-Drawer-2',
#  'look_at_obj_in_light-Pen-None-FloorLamp-221',
#  'pick_cool_then_place_in_recep-TomatoSliced-None-Microwave-30',
#  'pick_two_obj_and_place-PepperShaker-None-Drawer-15',
#  'pick_clean_then_place_in_recep-Kettle-None-StoveBurner-2',
#  'pick_heat_then_place_in_recep-Egg-None-GarbageCan-1',
#  'pick_two_obj_and_place-KeyChain-None-Dresser-330',
#  'pick_and_place_with_movable_recep-Ladle-Plate-Cabinet-16',
#  'pick_heat_then_place_in_recep-Egg-None-Fridge-17',
#  'look_at_obj_in_light-Box-None-FloorLamp-223',
#  'pick_clean_then_place_in_recep-Lettuce-None-CounterTop-13',
#  'pick_heat_then_place_in_recep-Potato-None-SinkBasin-30',
#  'pick_and_place_with_movable_recep-TomatoSliced-Pan-DiningTable-18',
#  'pick_heat_then_place_in_recep-Apple-None-Fridge-22',
#  'pick_two_obj_and_place-CreditCard-None-ArmChair-227',
#  'look_at_obj_in_light-Plate-None-FloorLamp-221',
#  'pick_heat_then_place_in_recep-AppleSliced-None-Fridge-24',
#  'pick_and_place_with_movable_recep-PotatoSliced-Pot-Fridge-20',
#  'pick_cool_then_place_in_recep-Apple-None-GarbageCan-5',
#  'pick_and_place_simple-TissueBox-None-Toilet-426',
#  'pick_heat_then_place_in_recep-Egg-None-Fridge-14',
#  'pick_heat_then_place_in_recep-Mug-None-Shelf-7',
#  'pick_clean_then_place_in_recep-SoapBar-None-GarbageCan-403',
#  'pick_heat_then_place_in_recep-Egg-None-CounterTop-8',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-323',
#  'pick_clean_then_place_in_recep-Knife-None-SideTable-3',
#  'pick_two_obj_and_place-RemoteControl-None-Sofa-228',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-CounterTop-27',
#  'pick_cool_then_place_in_recep-Mug-None-CoffeeMachine-16',
#  'pick_and_place_simple-CreditCard-None-Desk-307',
#  'pick_and_place_simple-SoapBottle-None-GarbageCan-11',
#  'pick_clean_then_place_in_recep-Ladle-None-CounterTop-20',
#  'pick_and_place_with_movable_recep-Spatula-Pan-SinkBasin-4',
#  'pick_two_obj_and_place-KeyChain-None-Dresser-322',
#  'pick_and_place_simple-SoapBottle-None-Toilet-426',
#  'pick_cool_then_place_in_recep-Mug-None-CoffeeMachine-14',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-SinkBasin-15',
#  'pick_two_obj_and_place-Pen-None-Dresser-229',
#  'pick_two_obj_and_place-KeyChain-None-ArmChair-222',
#  'pick_two_obj_and_place-SoapBar-None-Toilet-417',
#  'pick_and_place_with_movable_recep-RemoteControl-Box-CoffeeTable-211',
#  'pick_cool_then_place_in_recep-Pot-None-CounterTop-24',
#  'pick_and_place_with_movable_recep-Watch-Box-CoffeeTable-213',
#  'pick_clean_then_place_in_recep-Tomato-None-Fridge-20',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-303',
#  'pick_and_place_simple-SoapBottle-None-GarbageCan-419',
#  'pick_and_place_simple-RemoteControl-None-ArmChair-230',
#  'pick_and_place_simple-Plunger-None-Cabinet-405',
#  'pick_two_obj_and_place-Candle-None-Drawer-423',
#  'pick_and_place_with_movable_recep-Fork-Cup-DiningTable-26',
#  'pick_two_obj_and_place-ToiletPaper-None-Shelf-422',
#  'pick_and_place_simple-KeyChain-None-Dresser-317',
#  'pick_heat_then_place_in_recep-Potato-None-GarbageCan-12',
#  'pick_heat_then_place_in_recep-BreadSliced-None-GarbageCan-17',
#  'pick_and_place_simple-KeyChain-None-SideTable-330',
#  'pick_and_place_with_movable_recep-Tomato-Pan-CounterTop-21',
#  'pick_and_place_simple-HandTowel-None-BathtubBasin-408',
#  'look_at_obj_in_light-Laptop-None-FloorLamp-205',
#  'pick_and_place_simple-CellPhone-None-Dresser-317',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-221',
#  'pick_and_place_with_movable_recep-CreditCard-Plate-SideTable-214',
#  'pick_cool_then_place_in_recep-BreadSliced-None-GarbageCan-20',
#  'pick_two_obj_and_place-SoapBottle-None-Cabinet-414',
#  'pick_and_place_simple-Kettle-None-Shelf-1',
#  'look_at_obj_in_light-AlarmClock-None-DeskLamp-302',
#  'pick_cool_then_place_in_recep-Mug-None-Shelf-20',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-221',
#  'pick_and_place_simple-HandTowel-None-BathtubBasin-419',
#  'pick_two_obj_and_place-CreditCard-None-Dresser-311',
#  'look_at_obj_in_light-Box-None-DeskLamp-224',
#  'pick_cool_then_place_in_recep-Cup-None-Cabinet-30',
#  'pick_heat_then_place_in_recep-AppleSliced-None-Fridge-26',
#  'pick_and_place_with_movable_recep-ButterKnife-Pan-CounterTop-8',
#  'pick_two_obj_and_place-CreditCard-None-DiningTable-329',
#  'look_at_obj_in_light-RemoteControl-None-FloorLamp-225',
#  'pick_and_place_with_movable_recep-Pen-Bowl-Dresser-311',
#  'pick_clean_then_place_in_recep-Cloth-None-BathtubBasin-426',
#  'pick_clean_then_place_in_recep-Potato-None-Microwave-2',
#  'look_at_obj_in_light-Pillow-None-FloorLamp-221',
#  'pick_heat_then_place_in_recep-Cup-None-Cabinet-25',
#  'pick_and_place_simple-HandTowel-None-Cabinet-412',
#  'look_at_obj_in_light-Statue-None-FloorLamp-212',
#  'look_at_obj_in_light-TissueBox-None-FloorLamp-225',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-DiningTable-16',
#  'pick_and_place_simple-Watch-None-CoffeeTable-213',
#  'pick_two_obj_and_place-Book-None-Dresser-324',
#  'pick_cool_then_place_in_recep-Potato-None-SinkBasin-24',
#  'pick_two_obj_and_place-CD-None-GarbageCan-321',
#  'pick_two_obj_and_place-TissueBox-None-DiningTable-230',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-SideTable-21',
#  'pick_cool_then_place_in_recep-Potato-None-DiningTable-27',
#  'pick_clean_then_place_in_recep-Fork-None-Drawer-11',
#  'pick_heat_then_place_in_recep-AppleSliced-None-GarbageCan-2',
#  'pick_cool_then_place_in_recep-Pot-None-DiningTable-24',
#  'pick_and_place_with_movable_recep-Fork-Mug-SideTable-3',
#  'pick_cool_then_place_in_recep-Bread-None-CounterTop-15',
#  'pick_two_obj_and_place-CellPhone-None-Drawer-329',
#  'pick_and_place_with_movable_recep-KeyChain-Plate-Shelf-214',
#  'pick_heat_then_place_in_recep-Apple-None-SideTable-28',
#  'look_at_obj_in_light-Statue-None-FloorLamp-208',
#  'pick_cool_then_place_in_recep-Bowl-None-DiningTable-23',
#  'pick_clean_then_place_in_recep-Spatula-None-DiningTable-17',
#  'pick_and_place_with_movable_recep-AppleSliced-Pot-DiningTable-11',
#  'pick_two_obj_and_place-PepperShaker-None-DiningTable-18',
#  'pick_heat_then_place_in_recep-BreadSliced-None-Fridge-24',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-217',
#  'pick_heat_then_place_in_recep-Mug-None-Cabinet-19',
#  'pick_and_place_with_movable_recep-Spatula-Plate-SinkBasin-3',
#  'pick_and_place_with_movable_recep-Knife-Plate-SinkBasin-25',
#  'pick_clean_then_place_in_recep-SoapBar-None-BathtubBasin-429',
#  'pick_cool_then_place_in_recep-Lettuce-None-DiningTable-27',
#  'pick_clean_then_place_in_recep-Cloth-None-BathtubBasin-407',
#  'pick_and_place_with_movable_recep-ButterKnife-Plate-DiningTable-19',
#  'pick_cool_then_place_in_recep-TomatoSliced-None-Microwave-27',
#  'pick_cool_then_place_in_recep-TomatoSliced-None-GarbageCan-19',
#  'pick_two_obj_and_place-Cloth-None-Toilet-417',
#  'pick_and_place_with_movable_recep-Egg-Plate-CounterTop-19',
#  'look_at_obj_in_light-Watch-None-FloorLamp-225',
#  'pick_two_obj_and_place-Book-None-Dresser-317',
#  'pick_and_place_simple-Pencil-None-Shelf-310',
#  'pick_two_obj_and_place-SaltShaker-None-Cabinet-26',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-DiningTable-17',
#  'pick_and_place_simple-TennisRacket-None-Dresser-324',
#  'pick_two_obj_and_place-Fork-None-SinkBasin-23',
#  'pick_clean_then_place_in_recep-Ladle-None-Cabinet-2',
#  'pick_clean_then_place_in_recep-Lettuce-None-DiningTable-20',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-GarbageCan-25',
#  'pick_clean_then_place_in_recep-DishSponge-None-Cabinet-414',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-211',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-CounterTop-13',
#  'pick_clean_then_place_in_recep-Plate-None-Cabinet-13',
#  'pick_two_obj_and_place-Cup-None-Cabinet-2',
#  'pick_cool_then_place_in_recep-Tomato-None-GarbageCan-6',
#  'pick_cool_then_place_in_recep-Apple-None-SideTable-21',
#  'pick_two_obj_and_place-CreditCard-None-Safe-323',
#  'pick_cool_then_place_in_recep-PotatoSliced-None-Microwave-21',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-306',
#  'pick_and_place_simple-Newspaper-None-Sofa-211',
#  'pick_clean_then_place_in_recep-Cloth-None-BathtubBasin-427',
#  'pick_clean_then_place_in_recep-Cloth-None-CounterTop-410',
#  'look_at_obj_in_light-CD-None-DeskLamp-327',
#  'look_at_obj_in_light-AlarmClock-None-DeskLamp-309',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-212',
#  'pick_and_place_simple-Cloth-None-CounterTop-414',
#  'pick_two_obj_and_place-KeyChain-None-Ottoman-210',
#  'pick_cool_then_place_in_recep-Egg-None-CounterTop-27',
#  'pick_two_obj_and_place-CreditCard-None-Dresser-217',
#  'look_at_obj_in_light-Watch-None-FloorLamp-210',
#  'pick_and_place_with_movable_recep-ButterKnife-Pan-DiningTable-15',
#  'pick_and_place_simple-HandTowel-None-BathtubBasin-423',
#  'pick_heat_then_place_in_recep-BreadSliced-None-Fridge-6',
#  'pick_two_obj_and_place-CreditCard-None-Sofa-207',
#  'pick_and_place_simple-Book-None-ArmChair-209',
#  'pick_heat_then_place_in_recep-Apple-None-Fridge-12',
#  'pick_clean_then_place_in_recep-Ladle-None-Drawer-27',
#  'look_at_obj_in_light-Box-None-DeskLamp-303',
#  'pick_cool_then_place_in_recep-AppleSliced-None-GarbageCan-14',
#  'pick_clean_then_place_in_recep-SoapBar-None-Cabinet-418',
#  'pick_heat_then_place_in_recep-Cup-None-Cabinet-1',
#  'pick_cool_then_place_in_recep-Pot-None-CounterTop-1',
#  'pick_heat_then_place_in_recep-Cup-None-Fridge-18',
#  'pick_cool_then_place_in_recep-Bread-None-CounterTop-1',
#  'pick_and_place_simple-HandTowel-None-CounterTop-416',
#  'pick_two_obj_and_place-Candle-None-Drawer-409',
#  'pick_heat_then_place_in_recep-Apple-None-GarbageCan-2',
#  'look_at_obj_in_light-Plate-None-DeskLamp-218',
#  'pick_and_place_with_movable_recep-Watch-Plate-CoffeeTable-201',
#  'look_at_obj_in_light-Bowl-None-DeskLamp-305',
#  'pick_clean_then_place_in_recep-Cloth-None-BathtubBasin-402',
#  'pick_and_place_with_movable_recep-Spoon-Cup-DiningTable-27',
#  'pick_and_place_simple-Tomato-None-DiningTable-26',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-GarbageCan-11',
#  'pick_clean_then_place_in_recep-PotatoSliced-None-Microwave-6',
#  'pick_two_obj_and_place-DishSponge-None-Toilet-403',
#  'pick_and_place_simple-CellPhone-None-Drawer-324',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-SinkBasin-12',
#  'pick_and_place_simple-TissueBox-None-GarbageCan-427',
#  'pick_and_place_simple-Plunger-None-Cabinet-422',
#  'pick_and_place_simple-Laptop-None-ArmChair-205',
#  'pick_and_place_simple-ToiletPaper-None-ToiletPaperHanger-417',
#  'pick_and_place_with_movable_recep-DishSponge-Pot-SinkBasin-1',
#  'pick_cool_then_place_in_recep-AppleSliced-None-Microwave-23',
#  'pick_clean_then_place_in_recep-Ladle-None-DiningTable-16',
#  'pick_cool_then_place_in_recep-Pot-None-StoveBurner-23',
#  'pick_clean_then_place_in_recep-Ladle-None-Drawer-30',
#  'pick_and_place_simple-HandTowel-None-SinkBasin-415',
#  'pick_and_place_with_movable_recep-Fork-Plate-SinkBasin-25',
#  'pick_clean_then_place_in_recep-Mug-None-CoffeeMachine-21',
#  'pick_and_place_with_movable_recep-CellPhone-Plate-CoffeeTable-218',
#  'pick_clean_then_place_in_recep-Cloth-None-Toilet-411',
#  'pick_and_place_with_movable_recep-Pen-Plate-CoffeeTable-201',
#  'pick_clean_then_place_in_recep-Cloth-None-CounterTop-408',
#  'pick_heat_then_place_in_recep-Plate-None-DiningTable-28',
#  'pick_cool_then_place_in_recep-Potato-None-CounterTop-14',
#  'pick_two_obj_and_place-PotatoSliced-None-GarbageCan-28',
#  'pick_clean_then_place_in_recep-DishSponge-None-BathtubBasin-403',
#  'look_at_obj_in_light-CreditCard-None-DeskLamp-314',
#  'pick_heat_then_place_in_recep-Cup-None-Cabinet-3',
#  'pick_and_place_with_movable_recep-Pencil-Mug-Desk-323',
#  'pick_clean_then_place_in_recep-Pan-None-DiningTable-17',
#  'pick_and_place_with_movable_recep-Pencil-Mug-Shelf-303',
#  'pick_two_obj_and_place-SprayBottle-None-Toilet-422',
#  'pick_and_place_with_movable_recep-LettuceSliced-Pan-Fridge-20',
#  'pick_and_place_simple-Plunger-None-Cabinet-402',
#  'pick_and_place_simple-Book-None-Sofa-201',
#  'pick_two_obj_and_place-TissueBox-None-GarbageCan-230',
#  'pick_cool_then_place_in_recep-Pan-None-DiningTable-15',
#  'pick_and_place_with_movable_recep-AppleSliced-Pan-DiningTable-18',
#  'pick_and_place_simple-Pen-None-SideTable-329',
#  'pick_and_place_with_movable_recep-KeyChain-Box-CoffeeTable-228',
#  'pick_two_obj_and_place-SprayBottle-None-CounterTop-410',
#  'pick_two_obj_and_place-ToiletPaper-None-Drawer-413',
#  'pick_heat_then_place_in_recep-BreadSliced-None-Fridge-26',
#  'pick_and_place_with_movable_recep-Knife-Mug-SinkBasin-16',
#  'pick_clean_then_place_in_recep-Tomato-None-CounterTop-25',
#  'look_at_obj_in_light-Pen-None-DeskLamp-319',
#  'pick_and_place_simple-SoapBottle-None-Toilet-406',
#  'pick_and_place_simple-Pencil-None-Desk-302',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-5',
#  'look_at_obj_in_light-CellPhone-None-DeskLamp-316',
#  'pick_and_place_simple-ToiletPaper-None-ToiletPaperHanger-415',
#  'pick_and_place_with_movable_recep-CellPhone-Bowl-Desk-316',
#  'pick_heat_then_place_in_recep-Tomato-None-DiningTable-17',
#  'pick_heat_then_place_in_recep-Potato-None-SideTable-21',
#  'pick_two_obj_and_place-SprayBottle-None-Cabinet-403',
#  'pick_two_obj_and_place-SprayBottle-None-Toilet-430',
#  'pick_cool_then_place_in_recep-AppleSliced-None-GarbageCan-19',
#  'pick_cool_then_place_in_recep-Lettuce-None-GarbageCan-17',
#  'pick_two_obj_and_place-CreditCard-None-CoffeeTable-217',
#  'look_at_obj_in_light-Vase-None-FloorLamp-211',
#  'pick_and_place_simple-Mug-None-Dresser-311',
#  'pick_and_place_with_movable_recep-Spatula-Bowl-DiningTable-16',
#  'pick_and_place_simple-Statue-None-CoffeeTable-230',
#  'pick_heat_then_place_in_recep-Potato-None-GarbageCan-25',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-15',
#  'pick_and_place_simple-KeyChain-None-Desk-304',
#  'pick_two_obj_and_place-Laptop-None-Bed-311',
#  'pick_and_place_with_movable_recep-LettuceSliced-Pan-Fridge-16',
#  'pick_clean_then_place_in_recep-ButterKnife-None-CounterTop-8',
#  'pick_two_obj_and_place-CD-None-Shelf-326',
#  'pick_and_place_simple-Candle-None-Toilet-412',
#  'pick_clean_then_place_in_recep-Cloth-None-Shelf-415',
#  'pick_two_obj_and_place-BaseballBat-None-Bed-322',
#  'pick_clean_then_place_in_recep-Cloth-None-BathtubBasin-411',
#  'pick_and_place_with_movable_recep-Ladle-Pan-DiningTable-16',
#  'pick_and_place_with_movable_recep-ButterKnife-Pan-CounterTop-19',
#  'pick_heat_then_place_in_recep-AppleSliced-None-SideTable-28',
#  'look_at_obj_in_light-CellPhone-None-DeskLamp-320',
#  'pick_heat_then_place_in_recep-Mug-None-Cabinet-11',
#  'pick_and_place_simple-ToiletPaper-None-ToiletPaperHanger-423',
#  'pick_and_place_simple-Candle-None-CounterTop-411',
#  'pick_cool_then_place_in_recep-AppleSliced-None-Microwave-7',
#  'pick_and_place_with_movable_recep-Spoon-Cup-SinkBasin-15',
#  'pick_and_place_simple-CellPhone-None-Shelf-313',
#  'pick_and_place_simple-AlarmClock-None-Desk-307',
#  'pick_two_obj_and_place-SprayBottle-None-CounterTop-409',
#  'pick_cool_then_place_in_recep-PotatoSliced-None-DiningTable-27',
#  'pick_cool_then_place_in_recep-Bread-None-CounterTop-4',
#  'pick_two_obj_and_place-RemoteControl-None-CoffeeTable-202',
#  'pick_two_obj_and_place-Apple-None-GarbageCan-8',
#  'pick_two_obj_and_place-KeyChain-None-Dresser-318',
#  'look_at_obj_in_light-Pen-None-DeskLamp-327',
#  'pick_two_obj_and_place-PepperShaker-None-Cabinet-17',
#  'pick_cool_then_place_in_recep-Pan-None-StoveBurner-20',
#  'pick_and_place_with_movable_recep-AppleSliced-Pot-SinkBasin-1',
#  'pick_and_place_simple-SprayBottle-None-CounterTop-427',
#  'pick_cool_then_place_in_recep-AppleSliced-None-Microwave-25',
#  'pick_heat_then_place_in_recep-BreadSliced-None-CounterTop-11',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-SinkBasin-13',
#  'pick_and_place_simple-SoapBottle-None-CounterTop-417',
#  'look_at_obj_in_light-AlarmClock-None-DeskLamp-303',
#  'pick_two_obj_and_place-Pen-None-SideTable-326',
#  'pick_and_place_simple-Potato-None-Microwave-30',
#  'pick_heat_then_place_in_recep-AppleSliced-None-SinkBasin-30',
#  'pick_clean_then_place_in_recep-Cloth-None-Toilet-415',
#  'pick_heat_then_place_in_recep-AppleSliced-None-GarbageCan-20',
#  'pick_and_place_with_movable_recep-Pencil-Bowl-Dresser-330',
#  'pick_heat_then_place_in_recep-Apple-None-CounterTop-30',
#  'pick_heat_then_place_in_recep-Apple-None-Fridge-25',
#  'pick_and_place_simple-Watch-None-CoffeeTable-201',
#  'pick_cool_then_place_in_recep-Tomato-None-SinkBasin-14',
#  'pick_and_place_with_movable_recep-Apple-Pan-DiningTable-18',
#  'pick_two_obj_and_place-PepperShaker-None-Cabinet-8',
#  'pick_and_place_with_movable_recep-Pen-Bowl-SideTable-330',
#  'pick_two_obj_and_place-Cloth-None-SideTable-419',
#  'pick_cool_then_place_in_recep-BreadSliced-None-Microwave-27',
#  'pick_cool_then_place_in_recep-PotatoSliced-None-SideTable-21',
#  'pick_cool_then_place_in_recep-Apple-None-GarbageCan-2',
#  'pick_and_place_with_movable_recep-TomatoSliced-Pan-DiningTable-28',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-GarbageCan-25',
#  'pick_heat_then_place_in_recep-Potato-None-CounterTop-15',
#  'pick_clean_then_place_in_recep-SoapBar-None-BathtubBasin-411',
#  'look_at_obj_in_light-RemoteControl-None-FloorLamp-211',
#  'pick_clean_then_place_in_recep-Cloth-None-BathtubBasin-414',
#  'pick_two_obj_and_place-CD-None-Safe-317',
#  'pick_and_place_simple-CreditCard-None-ArmChair-206',
#  'pick_and_place_with_movable_recep-CreditCard-Box-Dresser-213',
#  'look_at_obj_in_light-BaseballBat-None-DeskLamp-303',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-206',
#  'pick_heat_then_place_in_recep-AppleSliced-None-Fridge-27',
#  'look_at_obj_in_light-Box-None-DeskLamp-205',
#  'pick_two_obj_and_place-CellPhone-None-Bed-306',
#  'pick_and_place_simple-ToiletPaper-None-ToiletPaperHanger-421',
#  'pick_cool_then_place_in_recep-Tomato-None-CounterTop-11',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-DiningTable-27',
#  'look_at_obj_in_light-Pen-None-DeskLamp-323',
#  'pick_clean_then_place_in_recep-Pan-None-StoveBurner-13',
#  'pick_heat_then_place_in_recep-AppleSliced-None-DiningTable-15',
#  'look_at_obj_in_light-Box-None-FloorLamp-205',
#  'pick_and_place_simple-SoapBottle-None-GarbageCan-411',
#  'pick_cool_then_place_in_recep-Apple-None-Microwave-22',
#  'look_at_obj_in_light-Book-None-DeskLamp-316',
#  'pick_cool_then_place_in_recep-Bowl-None-Shelf-7',
#  'pick_clean_then_place_in_recep-SoapBar-None-GarbageCan-426',
#  'pick_clean_then_place_in_recep-DishSponge-None-Shelf-20',
#  'pick_heat_then_place_in_recep-Plate-None-CounterTop-13',
#  'pick_clean_then_place_in_recep-Lettuce-None-CounterTop-15',
#  'look_at_obj_in_light-Statue-None-FloorLamp-205',
#  'pick_clean_then_place_in_recep-LettuceSliced-None-Fridge-22',
#  'pick_two_obj_and_place-Book-None-Bed-328',
#  'pick_two_obj_and_place-BreadSliced-None-Fridge-11',
#  'pick_and_place_simple-AppleSliced-None-Fridge-30',
#  'pick_heat_then_place_in_recep-Tomato-None-GarbageCan-2',
#  'pick_two_obj_and_place-Watch-None-SideTable-217',
#  'pick_cool_then_place_in_recep-Pan-None-CounterTop-22',
#  'pick_and_place_with_movable_recep-CD-Bowl-SideTable-330',
#  'pick_and_place_simple-Book-None-Desk-310',
#  'pick_and_place_with_movable_recep-Spoon-Cup-SinkBasin-6',
#  'pick_heat_then_place_in_recep-Plate-None-CounterTop-1',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-207',
#  'look_at_obj_in_light-AlarmClock-None-DeskLamp-323',
#  'pick_and_place_with_movable_recep-ButterKnife-Cup-SideTable-28',
#  'pick_two_obj_and_place-RemoteControl-None-ArmChair-208',
#  'pick_cool_then_place_in_recep-AppleSliced-None-DiningTable-18',
#  'look_at_obj_in_light-Newspaper-None-FloorLamp-224',
#  'pick_cool_then_place_in_recep-BreadSliced-None-CounterTop-12',
#  'look_at_obj_in_light-Cloth-None-DeskLamp-317',
#  'pick_clean_then_place_in_recep-LettuceSliced-None-Fridge-19',
#  'pick_heat_then_place_in_recep-AppleSliced-None-DiningTable-18',
#  'pick_and_place_with_movable_recep-ButterKnife-Cup-SinkBasin-4',
#  'pick_and_place_simple-SoapBottle-None-Toilet-413',
#  'pick_and_place_with_movable_recep-Knife-Mug-SideTable-3',
#  'pick_and_place_with_movable_recep-ButterKnife-Cup-CounterTop-26',
#  'pick_and_place_with_movable_recep-Fork-Cup-SinkBasin-6',
#  'pick_and_place_with_movable_recep-Spoon-Pot-CounterTop-17',
#  'pick_and_place_with_movable_recep-Knife-Pan-DiningTable-15',
#  'pick_and_place_simple-RemoteControl-None-Sofa-222',
#  'pick_cool_then_place_in_recep-Mug-None-CoffeeMachine-20',
#  'pick_two_obj_and_place-CD-None-Drawer-328',
#  'pick_and_place_simple-Pencil-None-SideTable-322',
#  'pick_cool_then_place_in_recep-PotatoSliced-None-Microwave-18',
#  'pick_and_place_with_movable_recep-Pencil-Mug-Desk-303',
#  'pick_and_place_with_movable_recep-ButterKnife-Cup-SinkBasin-7',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-218',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-309',
#  'pick_heat_then_place_in_recep-Apple-None-GarbageCan-18',
#  'pick_two_obj_and_place-Lettuce-None-Fridge-1',
#  'pick_and_place_with_movable_recep-AppleSliced-Pan-Fridge-18',
#  'pick_and_place_simple-Knife-None-SideTable-3',
#  'pick_two_obj_and_place-Cloth-None-Shelf-326',
#  'pick_two_obj_and_place-CreditCard-None-Desk-313',
#  'pick_two_obj_and_place-Kettle-None-DiningTable-18',
#  'pick_and_place_simple-SoapBar-None-Cart-401',
#  'pick_cool_then_place_in_recep-Pan-None-DiningTable-11',
#  'pick_and_place_with_movable_recep-TomatoSliced-Plate-DiningTable-15',
#  'pick_clean_then_place_in_recep-Ladle-None-CounterTop-8',
#  'pick_and_place_simple-HandTowel-None-BathtubBasin-410',
#  'pick_and_place_simple-TomatoSliced-None-Fridge-6',
#  'pick_two_obj_and_place-SoapBottle-None-Toilet-406',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-SinkBasin-5',
#  'pick_and_place_simple-SprayBottle-None-CounterTop-421',
#  'pick_and_place_with_movable_recep-Tomato-Plate-Fridge-17',
#  'look_at_obj_in_light-Box-None-DeskLamp-305',
#  'pick_cool_then_place_in_recep-Cup-None-Shelf-20',
#  'pick_clean_then_place_in_recep-Kettle-None-CounterTop-15',
#  'pick_two_obj_and_place-SoapBottle-None-GarbageCan-416',
#  'pick_two_obj_and_place-HandTowel-None-BathtubBasin-423',
#  'pick_and_place_simple-Laptop-None-Bed-302',
#  'pick_two_obj_and_place-SprayBottle-None-CounterTop-411',
#  'pick_heat_then_place_in_recep-Egg-None-GarbageCan-20',
#  'look_at_obj_in_light-RemoteControl-None-FloorLamp-224',
#  'pick_two_obj_and_place-Vase-None-SideTable-330',
#  'pick_clean_then_place_in_recep-Knife-None-SideTable-21',
#  'pick_and_place_simple-Candle-None-Dresser-413',
#  'pick_clean_then_place_in_recep-Spatula-None-SideTable-3',
#  'look_at_obj_in_light-CD-None-DeskLamp-302',
#  'pick_and_place_simple-ToiletPaper-None-ToiletPaperHanger-401',
#  'pick_heat_then_place_in_recep-Cup-None-CounterTop-14',
#  'pick_and_place_with_movable_recep-Spatula-Bowl-CounterTop-17',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-305',
#  'pick_clean_then_place_in_recep-TomatoSliced-None-Fridge-5',
#  'pick_and_place_simple-TissueBox-None-Dresser-301',
#  'look_at_obj_in_light-Statue-None-FloorLamp-224',
#  'pick_two_obj_and_place-CD-None-Drawer-319',
#  'pick_heat_then_place_in_recep-Egg-None-GarbageCan-8',
#  'pick_cool_then_place_in_recep-Pot-None-DiningTable-23',
#  'pick_clean_then_place_in_recep-Fork-None-DiningTable-15',
#  'look_at_obj_in_light-Newspaper-None-FloorLamp-203',
#  'pick_and_place_with_movable_recep-TomatoSliced-Bowl-Fridge-20',
#  'pick_and_place_with_movable_recep-Fork-Cup-SinkBasin-26',
#  'pick_clean_then_place_in_recep-Apple-None-DiningTable-19',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-CounterTop-16',
#  'pick_cool_then_place_in_recep-Apple-None-CounterTop-14',
#  'pick_and_place_simple-PepperShaker-None-CounterTop-27',
#  'pick_two_obj_and_place-ToiletPaper-None-Drawer-410',
#  'pick_cool_then_place_in_recep-Tomato-None-GarbageCan-5',
#  'pick_two_obj_and_place-SoapBottle-None-Cart-401',
#  'pick_and_place_with_movable_recep-TissueBox-Plate-DiningTable-203',
#  'pick_and_place_with_movable_recep-Pencil-Mug-Dresser-323',
#  'look_at_obj_in_light-WateringCan-None-DeskLamp-210',
#  'pick_cool_then_place_in_recep-TomatoSliced-None-DiningTable-18',
#  'pick_cool_then_place_in_recep-Tomato-None-Microwave-6',
#  'pick_clean_then_place_in_recep-DishSponge-None-Cart-401',
#  'pick_clean_then_place_in_recep-TomatoSliced-None-Microwave-20',
#  'pick_two_obj_and_place-Watch-None-Dresser-301',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-SideTable-21',
#  'pick_two_obj_and_place-CellPhone-None-SideTable-310',
#  'pick_and_place_simple-AlarmClock-None-Desk-318',
#  'pick_heat_then_place_in_recep-Potato-None-DiningTable-11',
#  'pick_cool_then_place_in_recep-Pot-None-StoveBurner-7',
#  'pick_cool_then_place_in_recep-PotatoSliced-None-DiningTable-24',
#  'pick_and_place_simple-Candle-None-Toilet-402',
#  'pick_two_obj_and_place-Book-None-Desk-302',
#  'pick_and_place_simple-Box-None-Sofa-205',
#  'pick_heat_then_place_in_recep-Potato-None-DiningTable-7',
#  'pick_and_place_with_movable_recep-PotatoSliced-Pot-Fridge-21',
#  'pick_cool_then_place_in_recep-Bread-None-CounterTop-16',
#  'pick_and_place_simple-SprayBottle-None-GarbageCan-415',
#  'pick_two_obj_and_place-Box-None-CoffeeTable-230',
#  'pick_clean_then_place_in_recep-SoapBar-None-Shelf-429',
#  'pick_heat_then_place_in_recep-Cup-None-SinkBasin-22',
#  'pick_two_obj_and_place-Book-None-Desk-310',
#  'pick_cool_then_place_in_recep-Cup-None-Cabinet-26',
#  'pick_clean_then_place_in_recep-Cup-None-SideTable-3',
#  'pick_two_obj_and_place-KeyChain-None-Ottoman-208',
#  'pick_two_obj_and_place-Candle-None-Toilet-417',
#  'pick_clean_then_place_in_recep-Potato-None-Microwave-23',
#  'pick_heat_then_place_in_recep-Apple-None-GarbageCan-12',
#  'pick_heat_then_place_in_recep-Plate-None-Cabinet-1',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-SinkBasin-23',
#  'pick_and_place_simple-TennisRacket-None-Bed-328',
#  'pick_two_obj_and_place-Cup-None-Microwave-22',
#  'pick_and_place_with_movable_recep-Potato-Bowl-Microwave-5',
#  'pick_cool_then_place_in_recep-Lettuce-None-DiningTable-26',
#  'pick_clean_then_place_in_recep-Cup-None-Microwave-14',
#  'pick_heat_then_place_in_recep-Potato-None-Fridge-11',
#  'pick_and_place_simple-CellPhone-None-ArmChair-321',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-307',
#  'pick_heat_then_place_in_recep-AppleSliced-None-Fridge-17',
#  'pick_clean_then_place_in_recep-SoapBar-None-Toilet-420',
#  'look_at_obj_in_light-BasketBall-None-DeskLamp-301',
#  'pick_clean_then_place_in_recep-SoapBar-None-Cabinet-403',
#  'pick_clean_then_place_in_recep-Cloth-None-Toilet-408',
#  'pick_and_place_simple-SprayBottle-None-GarbageCan-421',
#  'pick_and_place_simple-Statue-None-CoffeeTable-227',
#  'pick_two_obj_and_place-AlarmClock-None-Desk-304',
#  'pick_cool_then_place_in_recep-LettuceSliced-None-SinkBasin-19',
#  'look_at_obj_in_light-RemoteControl-None-FloorLamp-206',
#  'pick_two_obj_and_place-Newspaper-None-ArmChair-216',
#  'pick_and_place_with_movable_recep-CreditCard-Box-ArmChair-206',
#  'pick_and_place_with_movable_recep-Spoon-Plate-DiningTable-15',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-302',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-213',
#  'pick_two_obj_and_place-Spatula-None-Drawer-22',
#  'pick_heat_then_place_in_recep-AppleSliced-None-DiningTable-21',
#  'pick_clean_then_place_in_recep-PotatoSliced-None-Fridge-5',
#  'pick_cool_then_place_in_recep-BreadSliced-None-SideTable-21',
#  'pick_two_obj_and_place-HandTowel-None-SinkBasin-409',
#  'pick_clean_then_place_in_recep-Potato-None-Microwave-6',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-17',
#  'pick_cool_then_place_in_recep-Apple-None-DiningTable-15',
#  'pick_clean_then_place_in_recep-Cloth-None-Toilet-406',
#  'pick_cool_then_place_in_recep-Tomato-None-CounterTop-12',
#  'pick_cool_then_place_in_recep-Pan-None-StoveBurner-27',
#  'pick_and_place_simple-SoapBottle-None-Toilet-429',
#  'look_at_obj_in_light-Mug-None-DeskLamp-301',
#  'pick_heat_then_place_in_recep-Egg-None-Fridge-24',
#  'pick_and_place_with_movable_recep-ButterKnife-Cup-CounterTop-27',
#  'pick_and_place_simple-SoapBottle-None-CounterTop-428',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-20',
#  'pick_two_obj_and_place-CreditCard-None-DiningTable-311',
#  'pick_and_place_with_movable_recep-CreditCard-Bowl-Dresser-330',
#  'pick_two_obj_and_place-Candle-None-Drawer-411',
#  'pick_and_place_simple-TissueBox-None-SideTable-229',
#  'pick_two_obj_and_place-AlarmClock-None-Desk-307',
#  'pick_heat_then_place_in_recep-Cup-None-Fridge-23',
#  'pick_clean_then_place_in_recep-SoapBar-None-BathtubBasin-423',
#  'pick_two_obj_and_place-SoapBottle-None-CounterTop-411',
#  'pick_cool_then_place_in_recep-Plate-None-Shelf-20',
#  'pick_and_place_simple-SprayBottle-None-GarbageCan-410',
#  'pick_and_place_simple-Watch-None-DiningTable-326',
#  'pick_clean_then_place_in_recep-Mug-None-CoffeeMachine-26',
#  'pick_clean_then_place_in_recep-Kettle-None-Cabinet-11',
#  'look_at_obj_in_light-CD-None-DeskLamp-304',
#  'pick_and_place_with_movable_recep-AppleSliced-Pot-Fridge-24',
#  'pick_and_place_with_movable_recep-DishSponge-Plate-Cabinet-19',
#  'look_at_obj_in_light-Box-None-FloorLamp-212',
#  'pick_and_place_simple-Statue-None-SideTable-214',
#  'pick_cool_then_place_in_recep-Bread-None-DiningTable-15',
#  'pick_clean_then_place_in_recep-Bowl-None-Cabinet-13',
#  'pick_heat_then_place_in_recep-AppleSliced-None-SideTable-3',
#  'pick_clean_then_place_in_recep-ButterKnife-None-DiningTable-4',
#  'pick_two_obj_and_place-ToiletPaper-None-Toilet-413',
#  'pick_heat_then_place_in_recep-AppleSliced-None-Fridge-11',
#  'pick_and_place_with_movable_recep-Pencil-Mug-Desk-318',
#  'pick_and_place_simple-Newspaper-None-GarbageCan-214',
#  'pick_heat_then_place_in_recep-Potato-None-SideTable-3',
#  'pick_heat_then_place_in_recep-BreadSliced-None-Fridge-5',
#  'pick_two_obj_and_place-Book-None-Bed-304',
#  'pick_and_place_with_movable_recep-Pencil-Bowl-Dresser-311',
#  'pick_two_obj_and_place-Cloth-None-BathtubBasin-406',
#  'pick_cool_then_place_in_recep-Apple-None-Microwave-23',
#  'pick_and_place_simple-SprayBottle-None-Cabinet-403',
#  'pick_and_place_with_movable_recep-DishSponge-Pan-DiningTable-16',
#  'pick_clean_then_place_in_recep-Pan-None-Fridge-1',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-SinkBasin-4',
#  'pick_cool_then_place_in_recep-Pan-None-StoveBurner-23',
#  'pick_and_place_with_movable_recep-Pen-Mug-Desk-328',
#  'pick_and_place_with_movable_recep-Pencil-Bowl-CounterTop-311',
#  'pick_two_obj_and_place-RemoteControl-None-ArmChair-209',
#  'pick_and_place_simple-Book-None-Sofa-209',
#  'pick_and_place_simple-Candle-None-CounterTop-417',
#  'pick_two_obj_and_place-Pen-None-Desk-312',
#  'pick_and_place_simple-HandTowel-None-GarbageCan-420',
#  'pick_cool_then_place_in_recep-PotatoSliced-None-CounterTop-19',
#  'pick_heat_then_place_in_recep-Cup-None-Shelf-1',
#  'pick_cool_then_place_in_recep-Bread-None-CounterTop-25',
#  'look_at_obj_in_light-AlarmClock-None-DeskLamp-314',
#  'pick_and_place_with_movable_recep-LettuceSliced-Plate-SideTable-28',
#  'pick_and_place_simple-Box-None-Sofa-220',
#  'pick_cool_then_place_in_recep-Egg-None-SinkBasin-12',
#  'pick_and_place_with_movable_recep-Fork-Mug-DiningTable-15',
#  'pick_cool_then_place_in_recep-Apple-None-SinkBasin-11',
#  'pick_cool_then_place_in_recep-Mug-None-CoffeeMachine-30',
#  'pick_heat_then_place_in_recep-BreadSliced-None-Fridge-19',
#  'pick_and_place_with_movable_recep-TomatoSliced-Pan-DiningTable-23',
#  'pick_cool_then_place_in_recep-Mug-None-CoffeeMachine-6',
#  'pick_two_obj_and_place-CreditCard-None-ArmChair-206',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-GarbageCan-15',
#  'pick_two_obj_and_place-RemoteControl-None-ArmChair-217',
#  'pick_cool_then_place_in_recep-Plate-None-SinkBasin-19',
#  'pick_and_place_simple-SprayBottle-None-Toilet-405',
#  'look_at_obj_in_light-Newspaper-None-FloorLamp-227',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-27',
#  'pick_and_place_simple-CD-None-Shelf-310',
#  'pick_and_place_with_movable_recep-KeyChain-Box-Sofa-229',
#  'pick_and_place_simple-CellPhone-None-DiningTable-329',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-GarbageCan-3',
#  'pick_cool_then_place_in_recep-Mug-None-Cabinet-1',
#  'look_at_obj_in_light-WateringCan-None-FloorLamp-223',
#  'pick_two_obj_and_place-RemoteControl-None-ArmChair-224',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-Fridge-15',
#  'pick_and_place_simple-CellPhone-None-Bed-322',
#  'pick_clean_then_place_in_recep-Kettle-None-Shelf-1',
#  'look_at_obj_in_light-Pencil-None-FloorLamp-203',
#  'pick_clean_then_place_in_recep-Lettuce-None-Fridge-4',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-CounterTop-18',
#  'pick_two_obj_and_place-SaltShaker-None-SideTable-21',
#  'pick_two_obj_and_place-Fork-None-SinkBasin-14',
#  'pick_heat_then_place_in_recep-Cup-None-CounterTop-17',
#  'pick_and_place_with_movable_recep-Spoon-Cup-CounterTop-28',
#  'pick_and_place_with_movable_recep-ButterKnife-Mug-SideTable-28',
#  'look_at_obj_in_light-CD-None-DeskLamp-328',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-301',
#  'pick_two_obj_and_place-Pen-None-Drawer-311',
#  'pick_clean_then_place_in_recep-Cloth-None-Cabinet-405',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-GarbageCan-20',
#  'pick_and_place_with_movable_recep-CellPhone-Bowl-Desk-305',
#  'pick_and_place_with_movable_recep-Watch-Plate-SideTable-228',
#  'pick_clean_then_place_in_recep-Apple-None-Microwave-14',
#  'pick_heat_then_place_in_recep-Egg-None-SideTable-3',
#  'pick_heat_then_place_in_recep-Potato-None-Fridge-30',
#  'pick_clean_then_place_in_recep-Knife-None-Drawer-8',
#  'pick_and_place_with_movable_recep-TomatoSliced-Pot-Fridge-4',
#  'look_at_obj_in_light-Laptop-None-DeskLamp-323',
#  'pick_clean_then_place_in_recep-TomatoSliced-None-Microwave-30',
#  'pick_cool_then_place_in_recep-Egg-None-Microwave-6',
#  'pick_clean_then_place_in_recep-Knife-None-Drawer-22',
#  'pick_and_place_simple-Candle-None-Drawer-411',
#  'pick_heat_then_place_in_recep-Plate-None-Fridge-13',
#  'pick_and_place_simple-CellPhone-None-Desk-327',
#  'pick_heat_then_place_in_recep-Egg-None-GarbageCan-12',
#  'pick_two_obj_and_place-CreditCard-None-SideTable-326',
#  'look_at_obj_in_light-Statue-None-DeskLamp-216',
#  'pick_cool_then_place_in_recep-Potato-None-CounterTop-12',
#  'pick_clean_then_place_in_recep-LettuceSliced-None-Fridge-11',
#  'pick_heat_then_place_in_recep-Apple-None-DiningTable-24',
#  'pick_two_obj_and_place-Cup-None-CounterTop-4',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-216',
#  'look_at_obj_in_light-Laptop-None-DeskLamp-324',
#  'pick_clean_then_place_in_recep-Cloth-None-Toilet-426',
#  'pick_clean_then_place_in_recep-Pot-None-DiningTable-26',
#  'pick_cool_then_place_in_recep-BreadSliced-None-DiningTable-24',
#  'pick_and_place_with_movable_recep-Pen-Mug-CounterTop-311',
#  'pick_heat_then_place_in_recep-Mug-None-SideTable-3',
#  'pick_and_place_with_movable_recep-Spoon-Mug-DiningTable-28',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-11',
#  'pick_two_obj_and_place-Pen-None-Drawer-307',
#  'pick_heat_then_place_in_recep-Mug-None-Shelf-1',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-228',
#  'look_at_obj_in_light-AlarmClock-None-DeskLamp-305',
#  'pick_heat_then_place_in_recep-Apple-None-SideTable-21',
#  'pick_clean_then_place_in_recep-SoapBar-None-GarbageCan-429',
#  'pick_two_obj_and_place-CreditCard-None-ArmChair-230',
#  'pick_and_place_simple-RemoteControl-None-Sofa-207',
#  'pick_heat_then_place_in_recep-Egg-None-SideTable-28',
#  'pick_and_place_with_movable_recep-DishSponge-Pot-DiningTable-21',
#  'pick_heat_then_place_in_recep-Tomato-None-Fridge-24',
#  'pick_two_obj_and_place-ToiletPaper-None-Toilet-418',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-211',
#  'pick_and_place_simple-CreditCard-None-Desk-310',
#  'pick_and_place_with_movable_recep-TomatoSliced-Bowl-Microwave-19',
#  'pick_heat_then_place_in_recep-Mug-None-Cabinet-26',
#  'pick_and_place_simple-Pen-None-Drawer-305',
#  'look_at_obj_in_light-Watch-None-FloorLamp-228',
#  'look_at_obj_in_light-Bowl-None-DeskLamp-301',
#  'pick_cool_then_place_in_recep-Tomato-None-DiningTable-26',
#  'pick_clean_then_place_in_recep-Spoon-None-CounterTop-8',
#  'pick_and_place_simple-Box-None-Dresser-224',
#  'pick_two_obj_and_place-CellPhone-None-Sofa-218',
#  'pick_and_place_with_movable_recep-LettuceSliced-Pot-SinkBasin-4',
#  'pick_heat_then_place_in_recep-Egg-None-GarbageCan-11',
#  'pick_heat_then_place_in_recep-Plate-None-SinkBasin-7',
#  'pick_cool_then_place_in_recep-Apple-None-CounterTop-27',
#  'pick_and_place_simple-CellPhone-None-Dresser-330',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-16',
#  'pick_two_obj_and_place-Candle-None-Cabinet-402',
#  'pick_and_place_simple-ToiletPaper-None-Drawer-410',
#  'look_at_obj_in_light-AlarmClock-None-DeskLamp-316',
#  'look_at_obj_in_light-KeyChain-None-FloorLamp-210',
#  'pick_two_obj_and_place-WineBottle-None-GarbageCan-1',
#  'pick_and_place_simple-ToiletPaper-None-GarbageCan-416',
#  'pick_heat_then_place_in_recep-BreadSliced-None-CounterTop-24',
#  'look_at_obj_in_light-KeyChain-None-DeskLamp-327',
#  'pick_cool_then_place_in_recep-PotatoSliced-None-GarbageCan-14',
#  'pick_clean_then_place_in_recep-SoapBar-None-CounterTop-414',
#  'pick_and_place_with_movable_recep-PotatoSliced-Pot-Fridge-24',
#  'pick_clean_then_place_in_recep-SoapBar-None-Cabinet-413',
#  'pick_cool_then_place_in_recep-TomatoSliced-None-Microwave-17',
#  'pick_cool_then_place_in_recep-Tomato-None-Microwave-13',
#  'pick_and_place_simple-BaseballBat-None-Bed-326',
#  'pick_cool_then_place_in_recep-Bowl-None-SinkBasin-24',
#  'look_at_obj_in_light-Book-None-DeskLamp-306',
#  'pick_cool_then_place_in_recep-WineBottle-None-Cabinet-17',
#  'look_at_obj_in_light-CreditCard-None-FloorLamp-224',
#  'pick_and_place_with_movable_recep-Pencil-Mug-Desk-313',
#  'look_at_obj_in_light-Pencil-None-FloorLamp-212',
#  'pick_and_place_simple-SoapBottle-None-GarbageCan-417',
#  'pick_and_place_simple-AlarmClock-None-Dresser-319',
#  'pick_clean_then_place_in_recep-Pan-None-StoveBurner-2',
#  'pick_and_place_simple-Glassbottle-None-CounterTop-23',
#  'pick_clean_then_place_in_recep-ButterKnife-None-DiningTable-16',
#  'look_at_obj_in_light-Pencil-None-DeskLamp-320',
#  'pick_clean_then_place_in_recep-Pot-None-StoveBurner-26',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-GarbageCan-2',
#  'pick_two_obj_and_place-SprayBottle-None-GarbageCan-419',
#  'pick_two_obj_and_place-TissueBox-None-Drawer-216',
#  'pick_clean_then_place_in_recep-Egg-None-Microwave-30',
#  'look_at_obj_in_light-Pencil-None-DeskLamp-302',
#  'pick_and_place_with_movable_recep-CreditCard-Box-Sofa-228',
#  'pick_heat_then_place_in_recep-PotatoSliced-None-GarbageCan-26',
#  'pick_and_place_with_movable_recep-Knife-Plate-SinkBasin-16',
#  'pick_and_place_simple-ToiletPaper-None-ToiletPaperHanger-414',
#  'pick_two_obj_and_place-BreadSliced-None-GarbageCan-13',
#  'look_at_obj_in_light-Pillow-None-DeskLamp-218',
#  'pick_two_obj_and_place-DishSponge-None-BathtubBasin-427',
#  'pick_cool_then_place_in_recep-Cup-None-Cabinet-23',
#  'pick_clean_then_place_in_recep-PotatoSliced-None-DiningTable-24',
#  'pick_and_place_simple-Glassbottle-None-Fridge-16',
#  'pick_cool_then_place_in_recep-PotatoSliced-None-Microwave-11',
#  'pick_cool_then_place_in_recep-Plate-None-Shelf-7',
#  'pick_two_obj_and_place-ToiletPaper-None-Toilet-429',
#  'pick_and_place_with_movable_recep-Spoon-Cup-DiningTable-26',
#  'pick_cool_then_place_in_recep-AppleSliced-None-DiningTable-4',
#  'pick_cool_then_place_in_recep-Cup-None-Microwave-30',
#  'pick_and_place_simple-ToiletPaper-None-ToiletPaperHanger-409',
#  'pick_two_obj_and_place-Newspaper-None-Sofa-230',
#  'pick_heat_then_place_in_recep-TomatoSliced-None-GarbageCan-25',
#  'pick_and_place_with_movable_recep-KeyChain-Box-Sofa-228',
#  'pick_and_place_simple-Pillow-None-Sofa-221',
#  'pick_two_obj_and_place-Spoon-None-SideTable-3',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-13',
#  'pick_two_obj_and_place-AppleSliced-None-Microwave-21',
#  'pick_heat_then_place_in_recep-Mug-None-CoffeeMachine-22',
#  'pick_two_obj_and_place-CreditCard-None-ArmChair-217',
#  'pick_two_obj_and_place-Book-None-DiningTable-329',
#  'pick_and_place_with_movable_recep-RemoteControl-Box-ArmChair-202',
#  'pick_and_place_simple-AlarmClock-None-Shelf-310',
#  'look_at_obj_in_light-Pen-None-DeskLamp-309',
#  'pick_heat_then_place_in_recep-Cup-None-Fridge-12',
#  'look_at_obj_in_light-RemoteControl-None-FloorLamp-218',
#  'pick_heat_then_place_in_recep-BreadSliced-None-DiningTable-27',
#  'pick_and_place_simple-Kettle-None-StoveBurner-2',
#  'pick_and_place_with_movable_recep-Pen-Mug-SideTable-328',
#  'pick_two_obj_and_place-Bowl-None-Dresser-327',
#  'pick_two_obj_and_place-HandTowel-None-CounterTop-409',
#  'pick_cool_then_place_in_recep-Plate-None-DiningTable-23',
#  'pick_two_obj_and_place-AlarmClock-None-Dresser-318',
#  'pick_and_place_with_movable_recep-AppleSliced-Plate-Fridge-13',
#  ...]

# %%
# Analyze one task_dir

# %%
for task_dir in task_dirs:
    print(task_dir)
    trials = os.listdir(train_data_dir / task_dir)
    for trial in trials:
        json_file = os.listdir(train_data_dir / task_dir / trial)
        assert len(json_file) == 1, "Found more than one json file inside trial"
        json_file = json_file[0]
        assert json_file.endswith(".json"), f"{json_file} does not end with .json"
        
        #open json
        json_file_path = train_data_dir / task_dir / trial / json_file
        trial_data = json.load(json_file_path.open('r'))
    break
# Out:
# pick_and_place_with_movable_recep-DishSponge-Pan-DiningTable-20

# %%
idx = 2
instructions = copy.deepcopy(trial_data['turk_annotations']['anns'][idx]['high_descs'])

# %%
instructions
# Out:
# ['Turn around and walk between the island and the fridge to the counter with the green sponge on it.',
#  'Pick up the green sponge from the counter.',
#  'Turn to your left and walk to the front of the stove.',
#  'Place the sponge in the pan located on the back left burner of the stove.',
#  'Pick up the pan with the sponge in it.',
#  'Turn to your right and walk in the direction of the fridge, hang a right to stand at the long side of the island with stool in front of it.',
#  'Place the pan with the sponge in it behind the left-most loaf of bread and to the left of the apple.']

# %%
# shuffle
random.shuffle(instructions)
instructions
# Out:
# ['Turn around and walk between the island and the fridge to the counter with the green sponge on it.',
#  'Pick up the pan with the sponge in it.',
#  'Place the sponge in the pan located on the back left burner of the stove.',
#  'Place the pan with the sponge in it behind the left-most loaf of bread and to the left of the apple.',
#  'Turn to your right and walk in the direction of the fridge, hang a right to stand at the long side of the island with stool in front of it.',
#  'Pick up the green sponge from the counter.',
#  'Turn to your left and walk to the front of the stove.']

# %%
"""
Loop through to get all the data in a list of dict
Format: 
        [
            {'
                task': "...",
                'instructions: ["...", "..."]'
            }, 
            {'
                task': "...",
                'instructions: ["...", "..."]'
            }
        ]
"""

data_list = []
for task_dir in tqdm(task_dirs):
    #print(task_dir)
    trials = os.listdir(train_data_dir / task_dir)
    for trial in trials:
        json_file = os.listdir(train_data_dir / task_dir / trial)
        assert len(json_file) == 1, "Found more than one json file inside trial"
        json_file = json_file[0]
        assert json_file.endswith(".json"), f"{json_file} does not end with .json"
        
        #open json
        json_file_path = train_data_dir / task_dir / trial / json_file
        trial_data = json.load(json_file_path.open('r'))
        
        anns = trial_data['turk_annotations']['anns']
        for ann in anns:
            data = {}
            data['task'] = ann['task_desc']
            data['instructions'] = ann['high_descs']
            data_list.append(data)
# Out:
# 100%|██████████| 2435/2435 [00:32<00:00, 74.63it/s]

# %%
# %pwd
# Out:
# '/home/ksmehrab/EmbAIProject'

# %%
data_list_save_file = Path("./data/all_data.json")
json.dump(data_list, data_list_save_file.open('w'))

# %% [markdown]
# ## Begin shuffling with all_data.json

# %%
# Shuffle
data_list_save_file = Path("./data/all_data.json")
data_list = json.load(data_list_save_file.open('r'))

# %%
len(data_list)
# Out:
# 21025

# %%
"""
Create original sequences and shuffled sequences
Create this in two formats:

Format1 :

Two files. Each containing a list of instructions.
alfred_original_sequences.json -> list of original sequences. 
    Where each sequence is a list containing the task and instructions
alfred_shuffled_sequences.json -> list of shuffles sequences.
    Where each sequence is a list containing the task followed by the shuffled instructions
    
The original_sequences and shuffled_sequences need to map to each other. 
This means the orignal_sequences need to be repeated num_shuffles number of times.
"""

# Format 1
# alfred_original_sequences.json
num_shuffles = 4 
alfred_original_sequences = []
for data in tqdm(data_list):
    sequence = copy.deepcopy([data['task']])
    sequence.extend(data['instructions'])
    for i in range(num_shuffles):
        alfred_original_sequences.append(sequence)
# Out:
# 100%|██████████| 21025/21025 [00:00<00:00, 302362.53it/s]

# %%
alfred_original_sequences[:5]
# Out:
# [['Put a pan containing a sponge on the white table.',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it.',
#   'Pick up the green sponge on the left of the sink.',
#   'Turn left, and walk to the stove.',
#   'Place the sponge in the pan on the back left eye.',
#   'Pick up the pan with the sponge in it.',
#   'Turn right and walk until you have to turn right again and go to the white table.',
#   'Place the pan with the sponge inside on the upper left corner of the table.'],
#  ['Put a pan containing a sponge on the white table.',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it.',
#   'Pick up the green sponge on the left of the sink.',
#   'Turn left, and walk to the stove.',
#   'Place the sponge in the pan on the back left eye.',
#   'Pick up the pan with the sponge in it.',
#   'Turn right and walk until you have to turn right again and go to the white table.',
#   'Place the pan with the sponge inside on the upper left corner of the table.'],
#  ['Put a pan containing a sponge on the white table.',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it.',
#   'Pick up the green sponge on the left of the sink.',
#   'Turn left, and walk to the stove.',
#   'Place the sponge in the pan on the back left eye.',
#   'Pick up the pan with the sponge in it.',
#   'Turn right and walk until you have to turn right again and go to the white table.',
#   'Place the pan with the sponge inside on the upper left corner of the table.'],
#  ['Put a pan containing a sponge on the white table.',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it.',
#   'Pick up the green sponge on the left of the sink.',
#   'Turn left, and walk to the stove.',
#   'Place the sponge in the pan on the back left eye.',
#   'Pick up the pan with the sponge in it.',
#   'Turn right and walk until you have to turn right again and go to the white table.',
#   'Place the pan with the sponge inside on the upper left corner of the table.'],
#  ['Move a sponge and pan to the counter.',
#   'Turn around and turn left, then move forward to the counter.',
#   'Pick up the sponge from the back of the counter.',
#   'Carry the sponge and turn to the left, turn left at the counter and face the stove on the right.',
#   'Place the sponge on the pan that is on the left back burner.',
#   'Pick up the pan from the left back burner.',
#   'Carry the pan and turn around. Turn right and then face the island on the right.',
#   'Place the pan on the far back left side of the counter.']]

# %%
alfred_original_sequences_filepath = Path("./data/alfred_original_sequences.json")
json.dump(alfred_original_sequences, alfred_original_sequences_filepath.open('w'), indent=4)

# %%
# Format 2
# alfred_shuffled_sequences.json
alfred_shuffled_sequences = []

for data in tqdm(data_list):
    for i in range(num_shuffles):
        shuffled_sequence = copy.deepcopy([data['task']])
        shuffled_instructions = copy.deepcopy(data['instructions'])
        random.shuffle(shuffled_instructions)
        shuffled_sequence.extend(shuffled_instructions)
        alfred_shuffled_sequences.append(shuffled_sequence)
# Out:
# 100%|██████████| 21025/21025 [00:00<00:00, 24138.72it/s]

# %%
alfred_shuffled_sequences[:5]
# Out:
# [['Put a pan containing a sponge on the white table.',
#   'Turn left, and walk to the stove.',
#   'Pick up the green sponge on the left of the sink.',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it.',
#   'Pick up the pan with the sponge in it.',
#   'Place the sponge in the pan on the back left eye.',
#   'Turn right and walk until you have to turn right again and go to the white table.',
#   'Place the pan with the sponge inside on the upper left corner of the table.'],
#  ['Put a pan containing a sponge on the white table.',
#   'Pick up the green sponge on the left of the sink.',
#   'Place the sponge in the pan on the back left eye.',
#   'Turn left, and walk to the stove.',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it.',
#   'Turn right and walk until you have to turn right again and go to the white table.',
#   'Place the pan with the sponge inside on the upper left corner of the table.',
#   'Pick up the pan with the sponge in it.'],
#  ['Put a pan containing a sponge on the white table.',
#   'Place the sponge in the pan on the back left eye.',
#   'Place the pan with the sponge inside on the upper left corner of the table.',
#   'Turn right and walk until you have to turn right again and go to the white table.',
#   'Turn left, and walk to the stove.',
#   'Pick up the pan with the sponge in it.',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it.',
#   'Pick up the green sponge on the left of the sink.'],
#  ['Put a pan containing a sponge on the white table.',
#   'Place the pan with the sponge inside on the upper left corner of the table.',
#   'Place the sponge in the pan on the back left eye.',
#   'Turn left, and walk to the stove.',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it.',
#   'Pick up the pan with the sponge in it.',
#   'Turn right and walk until you have to turn right again and go to the white table.',
#   'Pick up the green sponge on the left of the sink.'],
#  ['Move a sponge and pan to the counter.',
#   'Place the pan on the far back left side of the counter.',
#   'Place the sponge on the pan that is on the left back burner.',
#   'Pick up the sponge from the back of the counter.',
#   'Turn around and turn left, then move forward to the counter.',
#   'Pick up the pan from the left back burner.',
#   'Carry the pan and turn around. Turn right and then face the island on the right.',
#   'Carry the sponge and turn to the left, turn left at the counter and face the stove on the right.']]

# %%
assert len(alfred_original_sequences) == len(alfred_shuffled_sequences) == len(data_list) * num_shuffles

# %%
alfred_shuffled_sequences_filepath = Path("./data/alfred_shuffled_sequences.json")
json.dump(alfred_shuffled_sequences, alfred_shuffled_sequences_filepath.open('w'), indent=4)

# %% [markdown]
# ### Create data files for finetuning NSGI format

# %%
"""
Create two files
    finetuning_alfred_original_sequences.json
    finetuning_alfred_shuffled_sequences.json

Format:

Convert each sequence from the original and shuffled lists to a string
 string format: "sequence[0] <-> sequence[1] ..."
"""

ft_orig_sequences = []
for sequences in alfred_original_sequences:
    # sequences is a list
    formatted_string = ' <-> '.join(sequences)
    ft_orig_sequences.append(formatted_string)

# %%
ft_orig_sequences[:5]
# Out:
# ['Put a pan containing a sponge on the white table. <-> Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> Pick up the green sponge on the left of the sink. <-> Turn left, and walk to the stove. <-> Place the sponge in the pan on the back left eye. <-> Pick up the pan with the sponge in it. <-> Turn right and walk until you have to turn right again and go to the white table. <-> Place the pan with the sponge inside on the upper left corner of the table.',
#  'Put a pan containing a sponge on the white table. <-> Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> Pick up the green sponge on the left of the sink. <-> Turn left, and walk to the stove. <-> Place the sponge in the pan on the back left eye. <-> Pick up the pan with the sponge in it. <-> Turn right and walk until you have to turn right again and go to the white table. <-> Place the pan with the sponge inside on the upper left corner of the table.',
#  'Put a pan containing a sponge on the white table. <-> Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> Pick up the green sponge on the left of the sink. <-> Turn left, and walk to the stove. <-> Place the sponge in the pan on the back left eye. <-> Pick up the pan with the sponge in it. <-> Turn right and walk until you have to turn right again and go to the white table. <-> Place the pan with the sponge inside on the upper left corner of the table.',
#  'Put a pan containing a sponge on the white table. <-> Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> Pick up the green sponge on the left of the sink. <-> Turn left, and walk to the stove. <-> Place the sponge in the pan on the back left eye. <-> Pick up the pan with the sponge in it. <-> Turn right and walk until you have to turn right again and go to the white table. <-> Place the pan with the sponge inside on the upper left corner of the table.',
#  'Move a sponge and pan to the counter. <-> Turn around and turn left, then move forward to the counter. <-> Pick up the sponge from the back of the counter. <-> Carry the sponge and turn to the left, turn left at the counter and face the stove on the right. <-> Place the sponge on the pan that is on the left back burner. <-> Pick up the pan from the left back burner. <-> Carry the pan and turn around. Turn right and then face the island on the right. <-> Place the pan on the far back left side of the counter.']

# %%
ft_orig_sequences_filepath = Path("./data/finetuning_alfred_original_sequences.json")
json.dump(ft_orig_sequences, ft_orig_sequences_filepath.open('w'), indent=4)

# %%
ft_shuffled_sequences = []
for shuff_seqs in alfred_shuffled_sequences:
    # shuff_seqs is a list
    formatted_string = ' <-> '.join(shuff_seqs)
    ft_shuffled_sequences.append(formatted_string)

# %%
ft_shuffled_sequences[:5]
# Out:
# ['Put a pan containing a sponge on the white table. <-> Turn left, and walk to the stove. <-> Pick up the green sponge on the left of the sink. <-> Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> Pick up the pan with the sponge in it. <-> Place the sponge in the pan on the back left eye. <-> Turn right and walk until you have to turn right again and go to the white table. <-> Place the pan with the sponge inside on the upper left corner of the table.',
#  'Put a pan containing a sponge on the white table. <-> Pick up the green sponge on the left of the sink. <-> Place the sponge in the pan on the back left eye. <-> Turn left, and walk to the stove. <-> Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> Turn right and walk until you have to turn right again and go to the white table. <-> Place the pan with the sponge inside on the upper left corner of the table. <-> Pick up the pan with the sponge in it.',
#  'Put a pan containing a sponge on the white table. <-> Place the sponge in the pan on the back left eye. <-> Place the pan with the sponge inside on the upper left corner of the table. <-> Turn right and walk until you have to turn right again and go to the white table. <-> Turn left, and walk to the stove. <-> Pick up the pan with the sponge in it. <-> Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> Pick up the green sponge on the left of the sink.',
#  'Put a pan containing a sponge on the white table. <-> Place the pan with the sponge inside on the upper left corner of the table. <-> Place the sponge in the pan on the back left eye. <-> Turn left, and walk to the stove. <-> Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> Pick up the pan with the sponge in it. <-> Turn right and walk until you have to turn right again and go to the white table. <-> Pick up the green sponge on the left of the sink.',
#  'Move a sponge and pan to the counter. <-> Place the pan on the far back left side of the counter. <-> Place the sponge on the pan that is on the left back burner. <-> Pick up the sponge from the back of the counter. <-> Turn around and turn left, then move forward to the counter. <-> Pick up the pan from the left back burner. <-> Carry the pan and turn around. Turn right and then face the island on the right. <-> Carry the sponge and turn to the left, turn left at the counter and face the stove on the right.']

# %%
ft_shuff_seqs_filepath = Path("./data/finetuning_alfred_shuffled_sequences.json")
json.dump(ft_shuffled_sequences, ft_shuff_seqs_filepath.open('w'), indent=4)

# %% [markdown]
# ### Prepare data in reference format

# %%
# Start with the original sequences 
from pathlib import Path
import json
alfred_original_sequences_filepath = Path("./data/alfred_original_sequences.json")
alfred_original_sequences = json.load(alfred_original_sequences_filepath.open('r'))

# Format it with the tokens
ref_sequences = []
for sequences in alfred_original_sequences:
    # sequences is a list
    formatted_sequences = []
    for instruction in sequences:
        formatted_sequences.append(instruction + " <-> ")
    ref_sequences.append(formatted_sequences)

# %%
ref_sequences_filepath = Path("./data/alfred_reference_step_libraries.json")
json
# Out:
# [['Put a pan containing a sponge on the white table. <-> ',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> ',
#   'Pick up the green sponge on the left of the sink. <-> ',
#   'Turn left, and walk to the stove. <-> ',
#   'Place the sponge in the pan on the back left eye. <-> ',
#   'Pick up the pan with the sponge in it. <-> ',
#   'Turn right and walk until you have to turn right again and go to the white table. <-> ',
#   'Place the pan with the sponge inside on the upper left corner of the table. <-> '],
#  ['Put a pan containing a sponge on the white table. <-> ',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> ',
#   'Pick up the green sponge on the left of the sink. <-> ',
#   'Turn left, and walk to the stove. <-> ',
#   'Place the sponge in the pan on the back left eye. <-> ',
#   'Pick up the pan with the sponge in it. <-> ',
#   'Turn right and walk until you have to turn right again and go to the white table. <-> ',
#   'Place the pan with the sponge inside on the upper left corner of the table. <-> '],
#  ['Put a pan containing a sponge on the white table. <-> ',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> ',
#   'Pick up the green sponge on the left of the sink. <-> ',
#   'Turn left, and walk to the stove. <-> ',
#   'Place the sponge in the pan on the back left eye. <-> ',
#   'Pick up the pan with the sponge in it. <-> ',
#   'Turn right and walk until you have to turn right again and go to the white table. <-> ',
#   'Place the pan with the sponge inside on the upper left corner of the table. <-> '],
#  ['Put a pan containing a sponge on the white table. <-> ',
#   'Turn around and walk to the wall and turn left and walk to the counter with the sink on it. <-> ',
#   'Pick up the green sponge on the left of the sink. <-> ',
#   'Turn left, and walk to the stove. <-> ',
#   'Place the sponge in the pan on the back left eye. <-> ',
#   'Pick up the pan with the sponge in it. <-> ',
#   'Turn right and walk until you have to turn right again and go to the white table. <-> ',
#   'Place the pan with the sponge inside on the upper left corner of the table. <-> '],
#  ['Move a sponge and pan to the counter. <-> ',
#   'Turn around and turn left, then move forward to the counter. <-> ',
#   'Pick up the sponge from the back of the counter. <-> ',
#   'Carry the sponge and turn to the left, turn left at the counter and face the stove on the right. <-> ',
#   'Place the sponge on the pan that is on the left back burner. <-> ',
#   'Pick up the pan from the left back burner. <-> ',
#   'Carry the pan and turn around. Turn right and then face the island on the right. <-> ',
#   'Place the pan on the far back left side of the counter. <-> '],
#  ['Move a sponge and pan to the counter. <-> ',
#   'Turn around and turn left, then move forward to the counter. <-> ',
#   'Pick up the sponge from the back of the counter. <-> ',
#   'Carry the sponge and turn to the left, turn left at the counter and face the stove on the right. <-> ',
#   'Place the sponge on the pan that is on the left back burner. <-> ',
#   'Pick up the pan from the left back burner. <-> ',
#   'Carry the pan and turn around. Turn right and then face the island on the right. <-> ',
#   'Place the pan on the far back left side of the counter. <-> '],
#  ['Move a sponge and pan to the counter. <-> ',
#   'Turn around and turn left, then move forward to the counter. <-> ',
#   'Pick up the sponge from the back of the counter. <-> ',
#   'Carry the sponge and turn to the left, turn left at the counter and face the stove on the right. <-> ',
#   'Place the sponge on the pan that is on the left back burner. <-> ',
#   'Pick up the pan from the left back burner. <-> ',
#   'Carry the pan and turn around. Turn right and then face the island on the right. <-> ',
#   'Place the pan on the far back left side of the counter. <-> '],
#  ['Move a sponge and pan to the counter. <-> ',
#   'Turn around and turn left, then move forward to the counter. <-> ',
#   'Pick up the sponge from the back of the counter. <-> ',
#   'Carry the sponge and turn to the left, turn left at the counter and face the stove on the right. <-> ',
#   'Place the sponge on the pan that is on the left back burner. <-> ',
#   'Pick up the pan from the left back burner. <-> ',
#   'Carry the pan and turn around. Turn right and then face the island on the right. <-> ',
#   'Place the pan on the far back left side of the counter. <-> '],
#  ['Pick up a sponge, place it in a pan, place the pan on the island <-> ',
#   'Turn around and walk between the island and the fridge to the counter with the green sponge on it. <-> ',
#   'Pick up the green sponge from the counter. <-> ',
#   'Turn to your left and walk to the front of the stove. <-> ',
#   'Place the sponge in the pan located on the back left burner of the stove. <-> ',
#   'Pick up the pan with the sponge in it. <-> ',
#   'Turn to your right and walk in the direction of the fridge, hang a right to stand at the long side of the island with stool in front of it. <-> ',
#   'Place the pan with the sponge in it behind the left-most loaf of bread and to the left of the apple. <-> '],
#  ['Pick up a sponge, place it in a pan, place the pan on the island <-> ',
#   'Turn around and walk between the island and the fridge to the counter with the green sponge on it. <-> ',
#   'Pick up the green sponge from the counter. <-> ',
#   'Turn to your left and walk to the front of the stove. <-> ',
#   'Place the sponge in the pan located on the back left burner of the stove. <-> ',
#   'Pick up the pan with the sponge in it. <-> ',
#   'Turn to your right and walk in the direction of the fridge, hang a right to stand at the long side of the island with stool in front of it. <-> ',
#   'Place the pan with the sponge in it behind the left-most loaf of bread and to the left of the apple. <-> '],
#  ['Pick up a sponge, place it in a pan, place the pan on the island <-> ',
#   'Turn around and walk between the island and the fridge to the counter with the green sponge on it. <-> ',
#   'Pick up the green sponge from the counter. <-> ',
#   'Turn to your left and walk to the front of the stove. <-> ',
#   'Place the sponge in the pan located on the back left burner of the stove. <-> ',
#   'Pick up the pan with the sponge in it. <-> ',
#   'Turn to your right and walk in the direction of the fridge, hang a right to stand at the long side of the island with stool in front of it. <-> ',
#   'Place the pan with the sponge in it behind the left-most loaf of bread and to the left of the apple. <-> '],
#  ['Pick up a sponge, place it in a pan, place the pan on the island <-> ',
#   'Turn around and walk between the island and the fridge to the counter with the green sponge on it. <-> ',
#   'Pick up the green sponge from the counter. <-> ',
#   'Turn to your left and walk to the front of the stove. <-> ',
#   'Place the sponge in the pan located on the back left burner of the stove. <-> ',
#   'Pick up the pan with the sponge in it. <-> ',
#   'Turn to your right and walk in the direction of the fridge, hang a right to stand at the long side of the island with stool in front of it. <-> ',
#   'Place the pan with the sponge in it behind the left-most loaf of bread and to the left of the apple. <-> '],
#  ['Examine the bat in by the light on the desk.  <-> ',
#   'Move to the mirror next to the bat on the ground. <-> ',
#   'Pick up the bat from the ground.  <-> ',
#   'Bring the bat to the lamp on the desk. <-> ',
#   'Turn on the lamp on the desk.  <-> '],
#  ['Examine the bat in by the light on the desk.  <-> ',
#   'Move to the mirror next to the bat on the ground. <-> ',
#   'Pick up the bat from the ground.  <-> ',
#   'Bring the bat to the lamp on the desk. <-> ',
#   'Turn on the lamp on the desk.  <-> '],
#  ['Examine the bat in by the light on the desk.  <-> ',
#   'Move to the mirror next to the bat on the ground. <-> ',
#   'Pick up the bat from the ground.  <-> ',
#   'Bring the bat to the lamp on the desk. <-> ',
#   'Turn on the lamp on the desk.  <-> '],
#  ['Examine the bat in by the light on the desk.  <-> ',
#   'Move to the mirror next to the bat on the ground. <-> ',
#   'Pick up the bat from the ground.  <-> ',
#   'Bring the bat to the lamp on the desk. <-> ',
#   'Turn on the lamp on the desk.  <-> '],
#  ['Examine a baseball bat using the light from a desk lamp. <-> ',
#   'Turn around and move towards the mirror on the door then turn right and face the corner of the room with the cord on the floor. <-> ',
#   'Pick up the baseball bat from the corner of the room. <-> ',
#   'Turn right and move towards the bed, then turn left at the bedside table and move forward to the desk next to the potted plant. <-> ',
#   'Turn on the desk lamp to the right of the chessboard and on the corner of the desk. <-> '],
#  ['Examine a baseball bat using the light from a desk lamp. <-> ',
#   'Turn around and move towards the mirror on the door then turn right and face the corner of the room with the cord on the floor. <-> ',
#   'Pick up the baseball bat from the corner of the room. <-> ',
#   'Turn right and move towards the bed, then turn left at the bedside table and move forward to the desk next to the potted plant. <-> ',
#   'Turn on the desk lamp to the right of the chessboard and on the corner of the desk. <-> '],
#  ['Examine a baseball bat using the light from a desk lamp. <-> ',
#   'Turn around and move towards the mirror on the door then turn right and face the corner of the room with the cord on the floor. <-> ',
#   'Pick up the baseball bat from the corner of the room. <-> ',
#   'Turn right and move towards the bed, then turn left at the bedside table and move forward to the desk next to the potted plant. <-> ',
#   'Turn on the desk lamp to the right of the chessboard and on the corner of the desk. <-> '],
#  ['Examine a baseball bat using the light from a desk lamp. <-> ',
#   'Turn around and move towards the mirror on the door then turn right and face the corner of the room with the cord on the floor. <-> ',
#   'Pick up the baseball bat from the corner of the room. <-> ',
#   'Turn right and move towards the bed, then turn left at the bedside table and move forward to the desk next to the potted plant. <-> ',
#   'Turn on the desk lamp to the right of the chessboard and on the corner of the desk. <-> '],
#  ['Turn the light on. <-> ',
#   'Move to the door. <-> ',
#   'Grab the baseball bat that is next to the door. <-> ',
#   'Turn around and move to the desk. <-> ',
#   'Turn the lamp on that is on the desk. <-> '],
#  ['Turn the light on. <-> ',
#   'Move to the door. <-> ',
#   'Grab the baseball bat that is next to the door. <-> ',
#   'Turn around and move to the desk. <-> ',
#   'Turn the lamp on that is on the desk. <-> '],
#  ['Turn the light on. <-> ',
#   'Move to the door. <-> ',
#   'Grab the baseball bat that is next to the door. <-> ',
#   'Turn around and move to the desk. <-> ',
#   'Turn the lamp on that is on the desk. <-> '],
#  ['Turn the light on. <-> ',
#   'Move to the door. <-> ',
#   'Grab the baseball bat that is next to the door. <-> ',
#   'Turn around and move to the desk. <-> ',
#   'Turn the lamp on that is on the desk. <-> '],
#  ['Turn on the lamp on the table.  <-> ',
#   'Turn to the left and move to the bat. <-> ',
#   'Pick up the bat from the corner <-> ',
#   'Bring the bat to the lamp on the table. <-> ',
#   'Turn on the lamp.  <-> '],
#  ['Turn on the lamp on the table.  <-> ',
#   'Turn to the left and move to the bat. <-> ',
#   'Pick up the bat from the corner <-> ',
#   'Bring the bat to the lamp on the table. <-> ',
#   'Turn on the lamp.  <-> '],
#  ['Turn on the lamp on the table.  <-> ',
#   'Turn to the left and move to the bat. <-> ',
#   'Pick up the bat from the corner <-> ',
#   'Bring the bat to the lamp on the table. <-> ',
#   'Turn on the lamp.  <-> '],
#  ['Turn on the lamp on the table.  <-> ',
#   'Turn to the left and move to the bat. <-> ',
#   'Pick up the bat from the corner <-> ',
#   'Bring the bat to the lamp on the table. <-> ',
#   'Turn on the lamp.  <-> '],
#  ['Examine a bat by the light of a lamp. <-> ',
#   'Turn left and walk towards the bat on the floor. <-> ',
#   'Pick up the bat from the floor. <-> ',
#   'Turn around, walk towards the bed, and turn left towards the lamp on the desk. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Examine a bat by the light of a lamp. <-> ',
#   'Turn left and walk towards the bat on the floor. <-> ',
#   'Pick up the bat from the floor. <-> ',
#   'Turn around, walk towards the bed, and turn left towards the lamp on the desk. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Examine a bat by the light of a lamp. <-> ',
#   'Turn left and walk towards the bat on the floor. <-> ',
#   'Pick up the bat from the floor. <-> ',
#   'Turn around, walk towards the bed, and turn left towards the lamp on the desk. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Examine a bat by the light of a lamp. <-> ',
#   'Turn left and walk towards the bat on the floor. <-> ',
#   'Pick up the bat from the floor. <-> ',
#   'Turn around, walk towards the bed, and turn left towards the lamp on the desk. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Examine a baseball bat by the light of a table lamp. <-> ',
#   'Turn left and walk towards the baseball bat on the floor. <-> ',
#   'Pick up the baseball bat from the floor. <-> ',
#   'Turn right and walk toward the table lamp at the other end of the room. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Examine a baseball bat by the light of a table lamp. <-> ',
#   'Turn left and walk towards the baseball bat on the floor. <-> ',
#   'Pick up the baseball bat from the floor. <-> ',
#   'Turn right and walk toward the table lamp at the other end of the room. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Examine a baseball bat by the light of a table lamp. <-> ',
#   'Turn left and walk towards the baseball bat on the floor. <-> ',
#   'Pick up the baseball bat from the floor. <-> ',
#   'Turn right and walk toward the table lamp at the other end of the room. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Examine a baseball bat by the light of a table lamp. <-> ',
#   'Turn left and walk towards the baseball bat on the floor. <-> ',
#   'Pick up the baseball bat from the floor. <-> ',
#   'Turn right and walk toward the table lamp at the other end of the room. <-> ',
#   'Turn on the lamp. <-> '],
#  ['To turn on the lamp while holding the bat. <-> ',
#   'Turn towards the door then to the right to the bat in the corner. <-> ',
#   'On the floor, pick up the bat. <-> ',
#   'Raise the bat then go right turning right at the desk. Walk towards the bed, turn left towards the lamp on the desk. <-> ',
#   'Turn on the lamp that is sitting on the desk. <-> '],
#  ['To turn on the lamp while holding the bat. <-> ',
#   'Turn towards the door then to the right to the bat in the corner. <-> ',
#   'On the floor, pick up the bat. <-> ',
#   'Raise the bat then go right turning right at the desk. Walk towards the bed, turn left towards the lamp on the desk. <-> ',
#   'Turn on the lamp that is sitting on the desk. <-> '],
#  ['To turn on the lamp while holding the bat. <-> ',
#   'Turn towards the door then to the right to the bat in the corner. <-> ',
#   'On the floor, pick up the bat. <-> ',
#   'Raise the bat then go right turning right at the desk. Walk towards the bed, turn left towards the lamp on the desk. <-> ',
#   'Turn on the lamp that is sitting on the desk. <-> '],
#  ['To turn on the lamp while holding the bat. <-> ',
#   'Turn towards the door then to the right to the bat in the corner. <-> ',
#   'On the floor, pick up the bat. <-> ',
#   'Raise the bat then go right turning right at the desk. Walk towards the bed, turn left towards the lamp on the desk. <-> ',
#   'Turn on the lamp that is sitting on the desk. <-> '],
#  ['Examine the bat by the light on the desk.  <-> ',
#   'Turn around to face the bat.  <-> ',
#   'Pick up the bat from the floor.  <-> ',
#   'Bring the bat to the desk. <-> ',
#   'Turn on the lamp on the desk. <-> '],
#  ['Examine the bat by the light on the desk.  <-> ',
#   'Turn around to face the bat.  <-> ',
#   'Pick up the bat from the floor.  <-> ',
#   'Bring the bat to the desk. <-> ',
#   'Turn on the lamp on the desk. <-> '],
#  ['Examine the bat by the light on the desk.  <-> ',
#   'Turn around to face the bat.  <-> ',
#   'Pick up the bat from the floor.  <-> ',
#   'Bring the bat to the desk. <-> ',
#   'Turn on the lamp on the desk. <-> '],
#  ['Examine the bat by the light on the desk.  <-> ',
#   'Turn around to face the bat.  <-> ',
#   'Pick up the bat from the floor.  <-> ',
#   'Bring the bat to the desk. <-> ',
#   'Turn on the lamp on the desk. <-> '],
#  ['Collect a baseball bat, turn on a lamp. <-> ',
#   'Turn around to face baseball bat. <-> ',
#   'Pick up the baseball bat on the floor. <-> ',
#   'Turn right for 2 steps, right again walk until you reach bed, turn left walk to desk. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Collect a baseball bat, turn on a lamp. <-> ',
#   'Turn around to face baseball bat. <-> ',
#   'Pick up the baseball bat on the floor. <-> ',
#   'Turn right for 2 steps, right again walk until you reach bed, turn left walk to desk. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Collect a baseball bat, turn on a lamp. <-> ',
#   'Turn around to face baseball bat. <-> ',
#   'Pick up the baseball bat on the floor. <-> ',
#   'Turn right for 2 steps, right again walk until you reach bed, turn left walk to desk. <-> ',
#   'Turn on the lamp. <-> '],
#  ['Collect a baseball bat, turn on a lamp. <-> ',
#   'Turn around to face baseball bat. <-> ',
#   'Pick up the baseball bat on the floor. <-> ',
#   'Turn right for 2 steps, right again walk until you reach bed, turn left walk to desk. <-> ',
#   'Turn on the lamp. <-> '],
#  ["Move the chef's knife from the black table to the kitchen sink. <-> ",
#   'Walk forward, hang a left and go to the black round table. <-> ',
#   "Pick up the chef's knife from the table. <-> ",
#   'Turn around and walk towards the sink. <-> ',
#   "Put the chef's knife in the sink basin. <-> "],
#  ["Move the chef's knife from the black table to the kitchen sink. <-> ",
#   'Walk forward, hang a left and go to the black round table. <-> ',
#   "Pick up the chef's knife from the table. <-> ",
#   'Turn around and walk towards the sink. <-> ',
#   "Put the chef's knife in the sink basin. <-> "],
#  ["Move the chef's knife from the black table to the kitchen sink. <-> ",
#   'Walk forward, hang a left and go to the black round table. <-> ',
#   "Pick up the chef's knife from the table. <-> ",
#   'Turn around and walk towards the sink. <-> ',
#   "Put the chef's knife in the sink basin. <-> "],
#  ["Move the chef's knife from the black table to the kitchen sink. <-> ",
#   'Walk forward, hang a left and go to the black round table. <-> ',
#   "Pick up the chef's knife from the table. <-> ",
#   'Turn around and walk towards the sink. <-> ',
#   "Put the chef's knife in the sink basin. <-> "],
#  ['Put the knife on the table in the sink. <-> ',
#   'Turn left and go to the black round table in the corner. <-> ',
#   'Pick up the yellow knife on the table.  <-> ',
#   'Turn right and go to the front of the sink. <-> ',
#   'Place the yellow knife in the sink. <-> '],
#  ['Put the knife on the table in the sink. <-> ',
#   'Turn left and go to the black round table in the corner. <-> ',
#   'Pick up the yellow knife on the table.  <-> ',
#   'Turn right and go to the front of the sink. <-> ',
#   'Place the yellow knife in the sink. <-> '],
#  ['Put the knife on the table in the sink. <-> ',
#   'Turn left and go to the black round table in the corner. <-> ',
#   'Pick up the yellow knife on the table.  <-> ',
#   'Turn right and go to the front of the sink. <-> ',
#   'Place the yellow knife in the sink. <-> '],
#  ['Put the knife on the table in the sink. <-> ',
#   'Turn left and go to the black round table in the corner. <-> ',
#   'Pick up the yellow knife on the table.  <-> ',
#   'Turn right and go to the front of the sink. <-> ',
#   'Place the yellow knife in the sink. <-> '],
#  ['take the yellow knife from the kitchen table, put it in the sink <-> ',
#   'head to the round table to the left <-> ',
#   'take the yellow knife from the table <-> ',
#   'turn around head across the kitchen to the sink <-> ',
#   'put the knife in the sink <-> '],
#  ['take the yellow knife from the kitchen table, put it in the sink <-> ',
#   'head to the round table to the left <-> ',
#   'take the yellow knife from the table <-> ',
#   'turn around head across the kitchen to the sink <-> ',
#   'put the knife in the sink <-> '],
#  ['take the yellow knife from the kitchen table, put it in the sink <-> ',
#   'head to the round table to the left <-> ',
#   'take the yellow knife from the table <-> ',
#   'turn around head across the kitchen to the sink <-> ',
#   'put the knife in the sink <-> '],
#  ['take the yellow knife from the kitchen table, put it in the sink <-> ',
#   'head to the round table to the left <-> ',
#   'take the yellow knife from the table <-> ',
#   'turn around head across the kitchen to the sink <-> ',
#   'put the knife in the sink <-> '],
#  ['Take the yellow knife and put it in the sink. <-> ',
#   'Turn around to find a circular black table across the room from the oven. <-> ',
#   'Pick up the yellow knife on the circular black table. <-> ',
#   'Turn around and walk directly back across the room to the oven to find a sink to the right of it. <-> ',
#   'Put the knife in the sink. <-> '],
#  ['Take the yellow knife and put it in the sink. <-> ',
#   'Turn around to find a circular black table across the room from the oven. <-> ',
#   'Pick up the yellow knife on the circular black table. <-> ',
#   'Turn around and walk directly back across the room to the oven to find a sink to the right of it. <-> ',
#   'Put the knife in the sink. <-> '],
#  ['Take the yellow knife and put it in the sink. <-> ',
#   'Turn around to find a circular black table across the room from the oven. <-> ',
#   'Pick up the yellow knife on the circular black table. <-> ',
#   'Turn around and walk directly back across the room to the oven to find a sink to the right of it. <-> ',
#   'Put the knife in the sink. <-> '],
#  ['Take the yellow knife and put it in the sink. <-> ',
#   'Turn around to find a circular black table across the room from the oven. <-> ',
#   'Pick up the yellow knife on the circular black table. <-> ',
#   'Turn around and walk directly back across the room to the oven to find a sink to the right of it. <-> ',
#   'Put the knife in the sink. <-> '],
#  ['Place a knife in a sink. <-> ',
#   'Turn around, hang a left at the door and walk to the black round table. <-> ',
#   'Pick up the knife to the right of the red apple on the table. <-> ',
#   'Turn around, hang a right at the door, walk to the stove ahead and face right towards the sink ahead. <-> ',
#   'Put the knife inside the sink next to the green sponge. <-> '],
#  ['Place a knife in a sink. <-> ',
#   'Turn around, hang a left at the door and walk to the black round table. <-> ',
#   'Pick up the knife to the right of the red apple on the table. <-> ',
#   'Turn around, hang a right at the door, walk to the stove ahead and face right towards the sink ahead. <-> ',
#   'Put the knife inside the sink next to the green sponge. <-> '],
#  ['Place a knife in a sink. <-> ',
#   'Turn around, hang a left at the door and walk to the black round table. <-> ',
#   'Pick up the knife to the right of the red apple on the table. <-> ',
#   'Turn around, hang a right at the door, walk to the stove ahead and face right towards the sink ahead. <-> ',
#   'Put the knife inside the sink next to the green sponge. <-> '],
#  ['Place a knife in a sink. <-> ',
#   'Turn around, hang a left at the door and walk to the black round table. <-> ',
#   'Pick up the knife to the right of the red apple on the table. <-> ',
#   'Turn around, hang a right at the door, walk to the stove ahead and face right towards the sink ahead. <-> ',
#   'Put the knife inside the sink next to the green sponge. <-> '],
#  ['Put a knife in the sink <-> ',
#   'Go to the round black table <-> ',
#   'Pick up the knife <-> ',
#   'Go to the sink <-> ',
#   'Put the knife in the sink <-> '],
#  ['Put a knife in the sink <-> ',
#   'Go to the round black table <-> ',
#   'Pick up the knife <-> ',
#   'Go to the sink <-> ',
#   'Put the knife in the sink <-> '],
#  ['Put a knife in the sink <-> ',
#   'Go to the round black table <-> ',
#   'Pick up the knife <-> ',
#   'Go to the sink <-> ',
#   'Put the knife in the sink <-> '],
#  ['Put a knife in the sink <-> ',
#   'Go to the round black table <-> ',
#   'Pick up the knife <-> ',
#   'Go to the sink <-> ',
#   'Put the knife in the sink <-> '],
#  ['Place a knife in a sink. <-> ',
#   'Turn left and walk straight ahead to the counter. <-> ',
#   'Pick up the knife on the counter. <-> ',
#   'Take a few steps right. <-> ',
#   'Place the knife in the sink. <-> '],
#  ['Place a knife in a sink. <-> ',
#   'Turn left and walk straight ahead to the counter. <-> ',
#   'Pick up the knife on the counter. <-> ',
#   'Take a few steps right. <-> ',
#   'Place the knife in the sink. <-> '],
#  ['Place a knife in a sink. <-> ',
#   'Turn left and walk straight ahead to the counter. <-> ',
#   'Pick up the knife on the counter. <-> ',
#   'Take a few steps right. <-> ',
#   'Place the knife in the sink. <-> '],
#  ['Place a knife in a sink. <-> ',
#   'Turn left and walk straight ahead to the counter. <-> ',
#   'Pick up the knife on the counter. <-> ',
#   'Take a few steps right. <-> ',
#   'Place the knife in the sink. <-> '],
#  ['Put a large metal knife in the sink. <-> ',
#   'Walk forward, then hang a left and walk over to the counter. <-> ',
#   'Pick up the large metal knife off of the counter to the left of the oven. <-> ',
#   'Walk over to the kitchen sink. <-> ',
#   'Put the metal knife into the sink basin handle up. <-> '],
#  ['Put a large metal knife in the sink. <-> ',
#   'Walk forward, then hang a left and walk over to the counter. <-> ',
#   'Pick up the large metal knife off of the counter to the left of the oven. <-> ',
#   'Walk over to the kitchen sink. <-> ',
#   'Put the metal knife into the sink basin handle up. <-> '],
#  ['Put a large metal knife in the sink. <-> ',
#   'Walk forward, then hang a left and walk over to the counter. <-> ',
#   'Pick up the large metal knife off of the counter to the left of the oven. <-> ',
#   'Walk over to the kitchen sink. <-> ',
#   'Put the metal knife into the sink basin handle up. <-> '],
#  ['Put a large metal knife in the sink. <-> ',
#   'Walk forward, then hang a left and walk over to the counter. <-> ',
#   'Pick up the large metal knife off of the counter to the left of the oven. <-> ',
#   'Walk over to the kitchen sink. <-> ',
#   'Put the metal knife into the sink basin handle up. <-> '],
#  ['Move knife from counter to sink. <-> ',
#   'Turn left, go across room to counter between stove and refrigerator. <-> ',
#   'Pick up knife to the right of the egg. <-> ',
#   'Turn right and proceed to sink on your left. <-> ',
#   'Stand up knife in sink to your left. <-> '],
#  ['Move knife from counter to sink. <-> ',
#   'Turn left, go across room to counter between stove and refrigerator. <-> ',
#   'Pick up knife to the right of the egg. <-> ',
#   'Turn right and proceed to sink on your left. <-> ',
#   'Stand up knife in sink to your left. <-> '],
#  ['Move knife from counter to sink. <-> ',
#   'Turn left, go across room to counter between stove and refrigerator. <-> ',
#   'Pick up knife to the right of the egg. <-> ',
#   'Turn right and proceed to sink on your left. <-> ',
#   'Stand up knife in sink to your left. <-> '],
#  ['Move knife from counter to sink. <-> ',
#   'Turn left, go across room to counter between stove and refrigerator. <-> ',
#   'Pick up knife to the right of the egg. <-> ',
#   'Turn right and proceed to sink on your left. <-> ',
#   'Stand up knife in sink to your left. <-> '],
#  ['Place a piece of sliced bread inside of a microwave.  <-> ',
#   'Turn right then walk towards the sink. <-> ',
#   'Pick up the knife with the yellow handle on the left side of the sink. <-> ',
#   'Turn all the way around then walk towards the wall, turn left towards the table. <-> ',
#   'Take the knife, then slice the loaf of bread on the table. <-> ',
#   'Turn left and walk towards the refrigerator, open the door. <-> ',
#   ' Place the knife on the second shelf, then close the door.  <-> ',
#   'Turn left then walk towards the wall, then turn left toward the table. <-> ',
#   'Pick up a slice of bread from the table. <-> ',
#   'Turn left walk towards the refrigerator, turn right. <-> ',
#   'Open the refrigerator door and place the slice of bread on the third shelf, then close the door. Open the door and remove the slice of bread from the third shelf and close the door. <-> ',
#   'Turn right and walk towards the sink. <-> ',
#   'Open the microwave door above the sink and place the slice of bread inside, then close the door. <-> '],
#  ['Place a piece of sliced bread inside of a microwave.  <-> ',
#   'Turn right then walk towards the sink. <-> ',
#   'Pick up the knife with the yellow handle on the left side of the sink. <-> ',
#   'Turn all the way around then walk towards the wall, turn left towards the table. <-> ',
#   'Take the knife, then slice the loaf of bread on the table. <-> ',
#   'Turn left and walk towards the refrigerator, open the door. <-> ',
#   ' Place the knife on the second shelf, then close the door.  <-> ',
#   'Turn left then walk towards the wall, then turn left toward the table. <-> ',
#   'Pick up a slice of bread from the table. <-> ',
#   'Turn left walk towards the refrigerator, turn right. <-> ',
#   'Open the refrigerator door and place the slice of bread on the third shelf, then close the door. Open the door and remove the slice of bread from the third shelf and close the door. <-> ',
#   'Turn right and walk towards the sink. <-> ',
#   'Open the microwave door above the sink and place the slice of bread inside, then close the door. <-> '],
#  ['Place a piece of sliced bread inside of a microwave.  <-> ',
#   'Turn right then walk towards the sink. <-> ',
#   'Pick up the knife with the yellow handle on the left side of the sink. <-> ',
#   'Turn all the way around then walk towards the wall, turn left towards the table. <-> ',
#   'Take the knife, then slice the loaf of bread on the table. <-> ',
#   'Turn left and walk towards the refrigerator, open the door. <-> ',
#   ' Place the knife on the second shelf, then close the door.  <-> ',
#   'Turn left then walk towards the wall, then turn left toward the table. <-> ',
#   'Pick up a slice of bread from the table. <-> ',
#   'Turn left walk towards the refrigerator, turn right. <-> ',
#   'Open the refrigerator door and place the slice of bread on the third shelf, then close the door. Open the door and remove the slice of bread from the third shelf and close the door. <-> ',
#   'Turn right and walk towards the sink. <-> ',
#   'Open the microwave door above the sink and place the slice of bread inside, then close the door. <-> '],
#  ['Place a piece of sliced bread inside of a microwave.  <-> ',
#   'Turn right then walk towards the sink. <-> ',
#   'Pick up the knife with the yellow handle on the left side of the sink. <-> ',
#   'Turn all the way around then walk towards the wall, turn left towards the table. <-> ',
#   'Take the knife, then slice the loaf of bread on the table. <-> ',
#   'Turn left and walk towards the refrigerator, open the door. <-> ',
#   ' Place the knife on the second shelf, then close the door.  <-> ',
#   'Turn left then walk towards the wall, then turn left toward the table. <-> ',
#   'Pick up a slice of bread from the table. <-> ',
#   'Turn left walk towards the refrigerator, turn right. <-> ',
#   'Open the refrigerator door and place the slice of bread on the third shelf, then close the door. Open the door and remove the slice of bread from the third shelf and close the door. <-> ',
#   'Turn right and walk towards the sink. <-> ',
#   'Open the microwave door above the sink and place the slice of bread inside, then close the door. <-> '],
#  ['Putting a slice of bread in the microwave <-> ',
#   'Turn right and head to the sink <-> ',
#   'Grab the large knife that is in front of the sink <-> ',
#   'Turn around and head to the white table <-> ',
#   'Cut the loaf of bread on the table into slices <-> ',
#   'Turn around and head to the fridge <-> ',
#   'Open the fridge and place the knife on the top rack <-> ',
#   'Turn around and face the white table <-> ',
#   'Grab a slice of bread off the table <-> ',
#   'Turn around and head to the fridge <-> ',
#   'Open the fridge and place the bread on the middle rack. Close the fridge. Open the fridge and grab the bread. <-> ',
#   'Turn to your right and head to the microwave <-> ',
#   'Open the microwave and put the bread inside <-> '],
#  ['Putting a slice of bread in the microwave <-> ',
#   'Turn right and head to the sink <-> ',
#   'Grab the large knife that is in front of the sink <-> ',
#   'Turn around and head to the white table <-> ',
#   'Cut the loaf of bread on the table into slices <-> ',
#   'Turn around and head to the fridge <-> ',
#   'Open the fridge and place the knife on the top rack <-> ',
#   'Turn around and face the white table <-> ',
#   'Grab a slice of bread off the table <-> ',
#   'Turn around and head to the fridge <-> ',
#   'Open the fridge and place the bread on the middle rack. Close the fridge. Open the fridge and grab the bread. <-> ',
#   'Turn to your right and head to the microwave <-> ',
#   'Open the microwave and put the bread inside <-> '],
#  ['Putting a slice of bread in the microwave <-> ',
#   'Turn right and head to the sink <-> ',
#   'Grab the large knife that is in front of the sink <-> ',
#   'Turn around and head to the white table <-> ',
#   'Cut the loaf of bread on the table into slices <-> ',
#   'Turn around and head to the fridge <-> ',
#   'Open the fridge and place the knife on the top rack <-> ',
#   'Turn around and face the white table <-> ',
#   'Grab a slice of bread off the table <-> ',
#   'Turn around and head to the fridge <-> ',
#   'Open the fridge and place the bread on the middle rack. Close the fridge. Open the fridge and grab the bread. <-> ',
#   'Turn to your right and head to the microwave <-> ',
#   'Open the microwave and put the bread inside <-> '],
#  ['Putting a slice of bread in the microwave <-> ',
#   'Turn right and head to the sink <-> ',
#   'Grab the large knife that is in front of the sink <-> ',
#   'Turn around and head to the white table <-> ',
#   'Cut the loaf of bread on the table into slices <-> ',
#   'Turn around and head to the fridge <-> ',
#   'Open the fridge and place the knife on the top rack <-> ',
#   'Turn around and face the white table <-> ',
#   'Grab a slice of bread off the table <-> ',
#   'Turn around and head to the fridge <-> ',
#   'Open the fridge and place the bread on the middle rack. Close the fridge. Open the fridge and grab the bread. <-> ',
#   'Turn to your right and head to the microwave <-> ',
#   'Open the microwave and put the bread inside <-> '],
#  ['Put the bread in the microwave. <-> ',
#   'Look down then turn right and walk to the counter. <-> ',
#   'Pick up the knife on the edge of the sink. <-> ',
#   'Turn around and walk towards the wall and turn left to face the table. <-> ',
#   'Use the knife to slice the bread on the table. <-> ',
#   'Turn left, walk up, and turn left again to open the fridge. <-> ',
#   'Place the knife inside the fridge and close the door. <-> ',
#   'Turn left and return to the table. <-> ',
#   'Pick up the first slice of bread off the table. <-> ',
#   'Return to the fridge and open the doors. <-> ',
#   'Place the bread in the fridge and close the doors, then open the doors and take the bread out and close the doors. <-> ',
#   'Head back towards the kitchen sink. <-> ',
#   'Put the slice of bread in the microwave. <-> '],
#  ['Put the bread in the microwave. <-> ',
#   'Look down then turn right and walk to the counter. <-> ',
#   'Pick up the knife on the edge of the sink. <-> ',
#   'Turn around and walk towards the wall and turn left to face the table. <-> ',
#   'Use the knife to slice the bread on the table. <-> ',
#   'Turn left, walk up, and turn left again to open the fridge. <-> ',
#   'Place the knife inside the fridge and close the door. <-> ',
#   'Turn left and return to the table. <-> ',
#   'Pick up the first slice of bread off the table. <-> ',
#   'Return to the fridge and open the doors. <-> ',
#   'Place the bread in the fridge and close the doors, then open the doors and take the bread out and close the doors. <-> ',
#   'Head back towards the kitchen sink. <-> ',
#   'Put the slice of bread in the microwave. <-> '],
#  ['Put the bread in the microwave. <-> ',
#   'Look down then turn right and walk to the counter. <-> ',
#   'Pick up the knife on the edge of the sink. <-> ',
#   'Turn around and walk towards the wall and turn left to face the table. <-> ',
#   'Use the knife to slice the bread on the table. <-> ',
#   'Turn left, walk up, and turn left again to open the fridge. <-> ',
#   'Place the knife inside the fridge and close the door. <-> ',
#   'Turn left and return to the table. <-> ',
#   'Pick up the first slice of bread off the table. <-> ',
#   'Return to the fridge and open the doors. <-> ',
#   'Place the bread in the fridge and close the doors, then open the doors and take the bread out and close the doors. <-> ',
#   'Head back towards the kitchen sink. <-> ',
#   'Put the slice of bread in the microwave. <-> '],
#  ['Put the bread in the microwave. <-> ',
#   'Look down then turn right and walk to the counter. <-> ',
#   'Pick up the knife on the edge of the sink. <-> ',
#   'Turn around and walk towards the wall and turn left to face the table. <-> ',
#   'Use the knife to slice the bread on the table. <-> ',
#   'Turn left, walk up, and turn left again to open the fridge. <-> ',
#   'Place the knife inside the fridge and close the door. <-> ',
#   'Turn left and return to the table. <-> ',
#   'Pick up the first slice of bread off the table. <-> ',
#   'Return to the fridge and open the doors. <-> ',
#   'Place the bread in the fridge and close the doors, then open the doors and take the bread out and close the doors. <-> ',
#   'Head back towards the kitchen sink. <-> ',
#   'Put the slice of bread in the microwave. <-> '],
#  ['Slice bread to put in microwave. <-> ',
#   'Turn and go to the sink. <-> ',
#   'Pick up the knife that is in front of the sink on the left side. <-> ',
#   'Turn all the way around and go to the right side of the white table with the knife. <-> ',
#   'With the knife slice the bread that is on the table. <-> ',
#   'With the knife in hand turn and go to the fridge. <-> ',
#   'While holding the knife open the fridge with other hand.  Place the knife on the second shelf of the fridge. <-> ',
#   'Turn and go to the right side of the white table. <-> ',
#   'Pick up a slice of bread that is closest to you. <-> ',
#   'Turn around with the slice of bread in your hand and go to the fridge. <-> ',
#   'Open the fridge. Place the bread on the third shelf and shut the fridge door.  Open the fridge door and pick up the bread slice that is on the third shelf.  Shut the door. <-> ',
#   'Turn with the slice of bread in hand and go to the microwave. <-> ',
#   'Open the microwave door and place the slice of bread to the left of the object in there.  Shut the microwave door. <-> '],
#  ['Slice bread to put in microwave. <-> ',
#   'Turn and go to the sink. <-> ',
#   'Pick up the knife that is in front of the sink on the left side. <-> ',
#   'Turn all the way around and go to the right side of the white table with the knife. <-> ',
#   'With the knife slice the bread that is on the table. <-> ',
#   'With the knife in hand turn and go to the fridge. <-> ',
#   'While holding the knife open the fridge with other hand.  Place the knife on the second shelf of the fridge. <-> ',
#   'Turn and go to the right side of the white table. <-> ',
#   'Pick up a slice of bread that is closest to you. <-> ',
#   'Turn around with the slice of bread in your hand and go to the fridge. <-> ',
#   'Open the fridge. Place the bread on the third shelf and shut the fridge door.  Open the fridge door and pick up the bread slice that is on the third shelf.  Shut the door. <-> ',
#   'Turn with the slice of bread in hand and go to the microwave. <-> ',
#   'Open the microwave door and place the slice of bread to the left of the object in there.  Shut the microwave door. <-> '],
#  ['Slice bread to put in microwave. <-> ',
#   'Turn and go to the sink. <-> ',
#   'Pick up the knife that is in front of the sink on the left side. <-> ',
#   'Turn all the way around and go to the right side of the white table with the knife. <-> ',
#   'With the knife slice the bread that is on the table. <-> ',
#   'With the knife in hand turn and go to the fridge. <-> ',
#   'While holding the knife open the fridge with other hand.  Place the knife on the second shelf of the fridge. <-> ',
#   'Turn and go to the right side of the white table. <-> ',
#   'Pick up a slice of bread that is closest to you. <-> ',
#   'Turn around with the slice of bread in your hand and go to the fridge. <-> ',
#   'Open the fridge. Place the bread on the third shelf and shut the fridge door.  Open the fridge door and pick up the bread slice that is on the third shelf.  Shut the door. <-> ',
#   'Turn with the slice of bread in hand and go to the microwave. <-> ',
#   'Open the microwave door and place the slice of bread to the left of the object in there.  Shut the microwave door. <-> '],
#  ['Slice bread to put in microwave. <-> ',
#   'Turn and go to the sink. <-> ',
#   'Pick up the knife that is in front of the sink on the left side. <-> ',
#   'Turn all the way around and go to the right side of the white table with the knife. <-> ',
#   'With the knife slice the bread that is on the table. <-> ',
#   'With the knife in hand turn and go to the fridge. <-> ',
#   'While holding the knife open the fridge with other hand.  Place the knife on the second shelf of the fridge. <-> ',
#   'Turn and go to the right side of the white table. <-> ',
#   'Pick up a slice of bread that is closest to you. <-> ',
#   'Turn around with the slice of bread in your hand and go to the fridge. <-> ',
#   'Open the fridge. Place the bread on the third shelf and shut the fridge door.  Open the fridge door and pick up the bread slice that is on the third shelf.  Shut the door. <-> ',
#   'Turn with the slice of bread in hand and go to the microwave. <-> ',
#   'Open the microwave door and place the slice of bread to the left of the object in there.  Shut the microwave door. <-> '],
#  ['To cool a slice of bread as well as put it in the microwave. <-> ',
#   'Turn right and walk up to the sink. <-> ',
#   'Pick up the knife on the edge of the seat. <-> ',
#   'Turn around and walk across the room and face the table on the left. <-> ',
#   'Cut of the loaf of bread into slices. <-> ',
#   'Turn around to face the fridge. <-> ',
#   'Put the knife in the fridge. <-> ',
#   'Turn around and walk over to the bread on the table. <-> ',
#   'Pick up a slice of the bread. <-> ',
#   'Turn around to face the fridge. <-> ',
#   'Put the slice of bread into the fridge, let it cool, then remove it. <-> ',
#   'Turn right and walk forward to face the microwave above the sink. <-> ',
#   'Place the slice of bread in the microwave. <-> '],
#  ['To cool a slice of bread as well as put it in the microwave. <-> ',
#   'Turn right and walk up to the sink. <-> ',
#   'Pick up the knife on the edge of the seat. <-> ',
#   'Turn around and walk across the room and face the table on the left. <-> ',
#   'Cut of the loaf of bread into slices. <-> ',
#   'Turn around to face the fridge. <-> ',
#   'Put the knife in the fridge. <-> ',
#   'Turn around and walk over to the bread on the table. <-> ',
#   'Pick up a slice of the bread. <-> ',
#   'Turn around to face the fridge. <-> ',
#   'Put the slice of bread into the fridge, let it cool, then remove it. <-> ',
#   'Turn right and walk forward to face the microwave above the sink. <-> ',
#   'Place the slice of bread in the microwave. <-> '],
#  ['To cool a slice of bread as well as put it in the microwave. <-> ',
#   'Turn right and walk up to the sink. <-> ',
#   'Pick up the knife on the edge of the seat. <-> ',
#   'Turn around and walk across the room and face the table on the left. <-> ',
#   'Cut of the loaf of bread into slices. <-> ',
#   'Turn around to face the fridge. <-> ',
#   'Put the knife in the fridge. <-> ',
#   'Turn around and walk over to the bread on the table. <-> ',
#   'Pick up a slice of the bread. <-> ',
#   'Turn around to face the fridge. <-> ',
#   'Put the slice of bread into the fridge, let it cool, then remove it. <-> ',
#   'Turn right and walk forward to face the microwave above the sink. <-> ',
#   'Place the slice of bread in the microwave. <-> '],
#  ['To cool a slice of bread as well as put it in the microwave. <-> ',
#   'Turn right and walk up to the sink. <-> ',
#   'Pick up the knife on the edge of the seat. <-> ',
#   'Turn around and walk across the room and face the table on the left. <-> ',
#   'Cut of the loaf of bread into slices. <-> ',
#   'Turn around to face the fridge. <-> ',
#   'Put the knife in the fridge. <-> ',
#   'Turn around and walk over to the bread on the table. <-> ',
#   'Pick up a slice of the bread. <-> ',
#   'Turn around to face the fridge. <-> ',
#   'Put the slice of bread into the fridge, let it cool, then remove it. <-> ',
#   'Turn right and walk forward to face the microwave above the sink. <-> ',
#   'Place the slice of bread in the microwave. <-> '],
#  ['place a cooled slice of bread in the microwave <-> ',
#   'turn left and walk to the end of the room, then turn right to face the kitchen counter <-> ',
#   'grab the butter knife off of the kitchen counter on the left side of the sink <-> ',
#   'turn right and walk to the kitchen counter to the left of the stove on your left at the end of the room <-> ',
#   'slice up the bread there on the counter <-> ',
#   'turn around and walk over to the first kitchen cabinet below the kitchen counters on your right <-> ',
#   'open the kitchen cabinet underneath the sink and place the buffer knife in there <-> ',
#   'turn right and walk back over to the kitchen counter with the bread on it next to the stove <-> ',
#   'grab a slice of bread off of the kitchen counter <-> ',
#   'turn around and walk to the fridge at the end of the room <-> ',
#   'place the bread inside the fridge, let it cool, then take it back out <-> ',
#   'turn right and walk forwards to the sink ahead, then look up at the microwave above <-> ',
#   'place the bread slice in the microwave above <-> '],
#  ['place a cooled slice of bread in the microwave <-> ',
#   'turn left and walk to the end of the room, then turn right to face the kitchen counter <-> ',
#   'grab the butter knife off of the kitchen counter on the left side of the sink <-> ',
#   'turn right and walk to the kitchen counter to the left of the stove on your left at the end of the room <-> ',
#   'slice up the bread there on the counter <-> ',
#   'turn around and walk over to the first kitchen cabinet below the kitchen counters on your right <-> ',
#   'open the kitchen cabinet underneath the sink and place the buffer knife in there <-> ',
#   'turn right and walk back over to the kitchen counter with the bread on it next to the stove <-> ',
#   'grab a slice of bread off of the kitchen counter <-> ',
#   'turn around and walk to the fridge at the end of the room <-> ',
#   'place the bread inside the fridge, let it cool, then take it back out <-> ',
#   'turn right and walk forwards to the sink ahead, then look up at the microwave above <-> ',
#   'place the bread slice in the microwave above <-> '],
#  ['place a cooled slice of bread in the microwave <-> ',
#   'turn left and walk to the end of the room, then turn right to face the kitchen counter <-> ',
#   'grab the butter knife off of the kitchen counter on the left side of the sink <-> ',
#   'turn right and walk to the kitchen counter to the left of the stove on your left at the end of the room <-> ',
#   'slice up the bread there on the counter <-> ',
#   'turn around and walk over to the first kitchen cabinet below the kitchen counters on your right <-> ',
#   'open the kitchen cabinet underneath the sink and place the buffer knife in there <-> ',
#   'turn right and walk back over to the kitchen counter with the bread on it next to the stove <-> ',
#   'grab a slice of bread off of the kitchen counter <-> ',
# ...
#   'Heat the tomato slice in the microwave and remove it. <-> ',
#   'Turn right and step forward to face the fridge. <-> ',
#   'Place the tomato slice in the fridge. <-> '],
#  ['To heat a tomato slice and place it in the fridge. <-> ',
#   'Take a step to the right to face the knife on the table. <-> ',
#   'Pick up the knife on the table. <-> ',
#   'Turn around and step forward to face the counter. <-> ',
#   'Cut the tomato on the counter into slices. <-> ',
#   'Turn right and cross the room to face the fridge. <-> ',
#   'Place the knife in the fridge. <-> ',
#   'Turn left and walk across the room to face the tomato. <-> ',
#   'Pick up the slice of tomato on the counter. <-> ',
#   'Take a step to the right to face the microwave. <-> ',
#   'Heat the tomato slice in the microwave and remove it. <-> ',
#   'Turn right and step forward to face the fridge. <-> ',
#   'Place the tomato slice in the fridge. <-> '],
#  ['Put a microwaved slice of tomato in the refrigerator.  <-> ',
#   'Turn and go to the table. <-> ',
#   'Pick up a knife on the table.  <-> ',
#   'Turn and go to the counter by the stove. <-> ',
#   'Cut the tomato on the counter.  <-> ',
#   'Turn and go to the refrigerator.  <-> ',
#   'Put the knife in the refrigerator.  <-> ',
#   'Turn and go to the counter by the stove.  <-> ',
#   'Pick up a slice of tomato on the counter.  <-> ',
#   'Turn and go to the microwave. <-> ',
#   'Heat the tomato slice in the microwave.  <-> ',
#   'Turn and go to the refrigerator.  <-> ',
#   'Put the slice of tomato in the refrigerator. <-> '],
#  ['Put a microwaved slice of tomato in the refrigerator.  <-> ',
#   'Turn and go to the table. <-> ',
#   'Pick up a knife on the table.  <-> ',
#   'Turn and go to the counter by the stove. <-> ',
#   'Cut the tomato on the counter.  <-> ',
#   'Turn and go to the refrigerator.  <-> ',
#   'Put the knife in the refrigerator.  <-> ',
#   'Turn and go to the counter by the stove.  <-> ',
#   'Pick up a slice of tomato on the counter.  <-> ',
#   'Turn and go to the microwave. <-> ',
#   'Heat the tomato slice in the microwave.  <-> ',
#   'Turn and go to the refrigerator.  <-> ',
#   'Put the slice of tomato in the refrigerator. <-> '],
#  ['Put a microwaved slice of tomato in the refrigerator.  <-> ',
#   'Turn and go to the table. <-> ',
#   'Pick up a knife on the table.  <-> ',
#   'Turn and go to the counter by the stove. <-> ',
#   'Cut the tomato on the counter.  <-> ',
#   'Turn and go to the refrigerator.  <-> ',
#   'Put the knife in the refrigerator.  <-> ',
#   'Turn and go to the counter by the stove.  <-> ',
#   'Pick up a slice of tomato on the counter.  <-> ',
#   'Turn and go to the microwave. <-> ',
#   'Heat the tomato slice in the microwave.  <-> ',
#   'Turn and go to the refrigerator.  <-> ',
#   'Put the slice of tomato in the refrigerator. <-> '],
#  ['Put a microwaved slice of tomato in the refrigerator.  <-> ',
#   'Turn and go to the table. <-> ',
#   'Pick up a knife on the table.  <-> ',
#   'Turn and go to the counter by the stove. <-> ',
#   'Cut the tomato on the counter.  <-> ',
#   'Turn and go to the refrigerator.  <-> ',
#   'Put the knife in the refrigerator.  <-> ',
#   'Turn and go to the counter by the stove.  <-> ',
#   'Pick up a slice of tomato on the counter.  <-> ',
#   'Turn and go to the microwave. <-> ',
#   'Heat the tomato slice in the microwave.  <-> ',
#   'Turn and go to the refrigerator.  <-> ',
#   'Put the slice of tomato in the refrigerator. <-> '],
#  ['To cool a tomato slice and place it in the microwave. <-> ',
#   'Turn around and walk across the room and turn left to face the end of the white table. <-> ',
#   'Pick up the knife on the white table. <-> ',
#   'Turn around to face the counter. <-> ',
#   'Cut the tomato on the counter into slices. <-> ',
#   'Place the knife on the counter. <-> ',
#   'Pick up a slice of tomato on the counter. <-> ',
#   'Take a step to the right to face the microwave. <-> ',
#   'Heat the tomato slice in the microwave and then remove it. <-> ',
#   'Turn around and walk forward to face the fridge. <-> ',
#   'Place the tomato slice in the fridge. <-> '],
#  ['To cool a tomato slice and place it in the microwave. <-> ',
#   'Turn around and walk across the room and turn left to face the end of the white table. <-> ',
#   'Pick up the knife on the white table. <-> ',
#   'Turn around to face the counter. <-> ',
#   'Cut the tomato on the counter into slices. <-> ',
#   'Place the knife on the counter. <-> ',
#   'Pick up a slice of tomato on the counter. <-> ',
#   'Take a step to the right to face the microwave. <-> ',
#   'Heat the tomato slice in the microwave and then remove it. <-> ',
#   'Turn around and walk forward to face the fridge. <-> ',
#   'Place the tomato slice in the fridge. <-> '],
#  ['To cool a tomato slice and place it in the microwave. <-> ',
#   'Turn around and walk across the room and turn left to face the end of the white table. <-> ',
#   'Pick up the knife on the white table. <-> ',
#   'Turn around to face the counter. <-> ',
#   'Cut the tomato on the counter into slices. <-> ',
#   'Place the knife on the counter. <-> ',
#   'Pick up a slice of tomato on the counter. <-> ',
#   'Take a step to the right to face the microwave. <-> ',
#   'Heat the tomato slice in the microwave and then remove it. <-> ',
#   'Turn around and walk forward to face the fridge. <-> ',
#   'Place the tomato slice in the fridge. <-> '],
#  ['To cool a tomato slice and place it in the microwave. <-> ',
#   'Turn around and walk across the room and turn left to face the end of the white table. <-> ',
#   'Pick up the knife on the white table. <-> ',
#   'Turn around to face the counter. <-> ',
#   'Cut the tomato on the counter into slices. <-> ',
#   'Place the knife on the counter. <-> ',
#   'Pick up a slice of tomato on the counter. <-> ',
#   'Take a step to the right to face the microwave. <-> ',
#   'Heat the tomato slice in the microwave and then remove it. <-> ',
#   'Turn around and walk forward to face the fridge. <-> ',
#   'Place the tomato slice in the fridge. <-> '],
#  ['Place a warm tomato slice in the fridge. <-> ',
#   'Turn around and face the table to your left. <-> ',
#   'Take the knife off of the table in front of you. <-> ',
#   'Turn left and face the counter by the stove on your left. <-> ',
#   'Slice the tomato on the counter in front of you. <-> ',
#   'Place the knife on the counter in front of you. <-> ',
#   'Take a tomato slice off of the counter in front of you. <-> ',
#   'Turn right and face the microwave on top of the stove to your left. <-> ',
#   'Heat up the tomato slice in the microwave in front of you, take the tomato out and close the microwave. <-> ',
#   'Turn around and face the fridge on your left. <-> ',
#   'Place the tomato slice in the fridge in front of you and close it. <-> '],
#  ['Place a warm tomato slice in the fridge. <-> ',
#   'Turn around and face the table to your left. <-> ',
#   'Take the knife off of the table in front of you. <-> ',
#   'Turn left and face the counter by the stove on your left. <-> ',
#   'Slice the tomato on the counter in front of you. <-> ',
#   'Place the knife on the counter in front of you. <-> ',
#   'Take a tomato slice off of the counter in front of you. <-> ',
#   'Turn right and face the microwave on top of the stove to your left. <-> ',
#   'Heat up the tomato slice in the microwave in front of you, take the tomato out and close the microwave. <-> ',
#   'Turn around and face the fridge on your left. <-> ',
#   'Place the tomato slice in the fridge in front of you and close it. <-> '],
#  ['Place a warm tomato slice in the fridge. <-> ',
#   'Turn around and face the table to your left. <-> ',
#   'Take the knife off of the table in front of you. <-> ',
#   'Turn left and face the counter by the stove on your left. <-> ',
#   'Slice the tomato on the counter in front of you. <-> ',
#   'Place the knife on the counter in front of you. <-> ',
#   'Take a tomato slice off of the counter in front of you. <-> ',
#   'Turn right and face the microwave on top of the stove to your left. <-> ',
#   'Heat up the tomato slice in the microwave in front of you, take the tomato out and close the microwave. <-> ',
#   'Turn around and face the fridge on your left. <-> ',
#   'Place the tomato slice in the fridge in front of you and close it. <-> '],
#  ['Place a warm tomato slice in the fridge. <-> ',
#   'Turn around and face the table to your left. <-> ',
#   'Take the knife off of the table in front of you. <-> ',
#   'Turn left and face the counter by the stove on your left. <-> ',
#   'Slice the tomato on the counter in front of you. <-> ',
#   'Place the knife on the counter in front of you. <-> ',
#   'Take a tomato slice off of the counter in front of you. <-> ',
#   'Turn right and face the microwave on top of the stove to your left. <-> ',
#   'Heat up the tomato slice in the microwave in front of you, take the tomato out and close the microwave. <-> ',
#   'Turn around and face the fridge on your left. <-> ',
#   'Place the tomato slice in the fridge in front of you and close it. <-> '],
#  ['Put the heated slice tomato in the fridge <-> ',
#   'Turn left then go to the right side of the table <-> ',
#   'Pick up the knife on the table <-> ',
#   'Turn left then head to the counter beside the stove <-> ',
#   'Cut the tomato on the counter <-> ',
#   'Put the knife on the counter <-> ',
#   'Pick up a slice of tomato <-> ',
#   'Turn right then head to the microwave <-> ',
#   'Open the microwave, put in and out the tomato slice then close microwave <-> ',
#   'Look down then turn right head to the fridge <-> ',
#   'Open the fridge and put in the slice of tomato then close the fridge <-> '],
#  ['Put the heated slice tomato in the fridge <-> ',
#   'Turn left then go to the right side of the table <-> ',
#   'Pick up the knife on the table <-> ',
#   'Turn left then head to the counter beside the stove <-> ',
#   'Cut the tomato on the counter <-> ',
#   'Put the knife on the counter <-> ',
#   'Pick up a slice of tomato <-> ',
#   'Turn right then head to the microwave <-> ',
#   'Open the microwave, put in and out the tomato slice then close microwave <-> ',
#   'Look down then turn right head to the fridge <-> ',
#   'Open the fridge and put in the slice of tomato then close the fridge <-> '],
#  ['Put the heated slice tomato in the fridge <-> ',
#   'Turn left then go to the right side of the table <-> ',
#   'Pick up the knife on the table <-> ',
#   'Turn left then head to the counter beside the stove <-> ',
#   'Cut the tomato on the counter <-> ',
#   'Put the knife on the counter <-> ',
#   'Pick up a slice of tomato <-> ',
#   'Turn right then head to the microwave <-> ',
#   'Open the microwave, put in and out the tomato slice then close microwave <-> ',
#   'Look down then turn right head to the fridge <-> ',
#   'Open the fridge and put in the slice of tomato then close the fridge <-> '],
#  ['Put the heated slice tomato in the fridge <-> ',
#   'Turn left then go to the right side of the table <-> ',
#   'Pick up the knife on the table <-> ',
#   'Turn left then head to the counter beside the stove <-> ',
#   'Cut the tomato on the counter <-> ',
#   'Put the knife on the counter <-> ',
#   'Pick up a slice of tomato <-> ',
#   'Turn right then head to the microwave <-> ',
#   'Open the microwave, put in and out the tomato slice then close microwave <-> ',
#   'Look down then turn right head to the fridge <-> ',
#   'Open the fridge and put in the slice of tomato then close the fridge <-> '],
#  ['Examine the lamp in the light of the tall lamp.  <-> ',
#   'Turn right, head around the table to face the white vase on the table.  <-> ',
#   'Pick up the vase on the table.  <-> ',
#   'Bring the vase to the lamp, left of the tv.  <-> ',
#   'Turn on the tall lamp on the ground.  <-> '],
#  ['Examine the lamp in the light of the tall lamp.  <-> ',
#   'Turn right, head around the table to face the white vase on the table.  <-> ',
#   'Pick up the vase on the table.  <-> ',
#   'Bring the vase to the lamp, left of the tv.  <-> ',
#   'Turn on the tall lamp on the ground.  <-> '],
#  ['Examine the lamp in the light of the tall lamp.  <-> ',
#   'Turn right, head around the table to face the white vase on the table.  <-> ',
#   'Pick up the vase on the table.  <-> ',
#   'Bring the vase to the lamp, left of the tv.  <-> ',
#   'Turn on the tall lamp on the ground.  <-> '],
#  ['Examine the lamp in the light of the tall lamp.  <-> ',
#   'Turn right, head around the table to face the white vase on the table.  <-> ',
#   'Pick up the vase on the table.  <-> ',
#   'Bring the vase to the lamp, left of the tv.  <-> ',
#   'Turn on the tall lamp on the ground.  <-> '],
#  ['Turn a lamp on while holding a vase. <-> ',
#   'Turn to the right and then right again before turning to face the glass table. <-> ',
#   'Pick the white vase up from the table. <-> ',
#   'Cross the room to face the floor lamp by the television. <-> ',
#   'Turn the lamp on. <-> '],
#  ['Turn a lamp on while holding a vase. <-> ',
#   'Turn to the right and then right again before turning to face the glass table. <-> ',
#   'Pick the white vase up from the table. <-> ',
#   'Cross the room to face the floor lamp by the television. <-> ',
#   'Turn the lamp on. <-> '],
#  ['Turn a lamp on while holding a vase. <-> ',
#   'Turn to the right and then right again before turning to face the glass table. <-> ',
#   'Pick the white vase up from the table. <-> ',
#   'Cross the room to face the floor lamp by the television. <-> ',
#   'Turn the lamp on. <-> '],
#  ['Turn a lamp on while holding a vase. <-> ',
#   'Turn to the right and then right again before turning to face the glass table. <-> ',
#   'Pick the white vase up from the table. <-> ',
#   'Cross the room to face the floor lamp by the television. <-> ',
#   'Turn the lamp on. <-> '],
#  ['Carry a vase while turning on a lamp <-> ',
#   'Move across the room to the glass coffee table facing the white vase <-> ',
#   'Pick up the white vase on top of the coffee table <-> ',
#   'Carry the vase Across the room to the floor lamp to the right of the TV <-> ',
#   'Turn on the lamp <-> '],
#  ['Carry a vase while turning on a lamp <-> ',
#   'Move across the room to the glass coffee table facing the white vase <-> ',
#   'Pick up the white vase on top of the coffee table <-> ',
#   'Carry the vase Across the room to the floor lamp to the right of the TV <-> ',
#   'Turn on the lamp <-> '],
#  ['Carry a vase while turning on a lamp <-> ',
#   'Move across the room to the glass coffee table facing the white vase <-> ',
#   'Pick up the white vase on top of the coffee table <-> ',
#   'Carry the vase Across the room to the floor lamp to the right of the TV <-> ',
#   'Turn on the lamp <-> '],
#  ['Carry a vase while turning on a lamp <-> ',
#   'Move across the room to the glass coffee table facing the white vase <-> ',
#   'Pick up the white vase on top of the coffee table <-> ',
#   'Carry the vase Across the room to the floor lamp to the right of the TV <-> ',
#   'Turn on the lamp <-> '],
#  ['grab the yellow bottle on the coffee table, turn on the light behind the TV <-> ',
#   'turn left, walk around the coffee table to the other side <-> ',
#   'grab the yellow bottle near the edge <-> ',
#   'turn left, walk around the chairs to the corner of the room  <-> ',
#   'turn on the light behind the TV <-> '],
#  ['grab the yellow bottle on the coffee table, turn on the light behind the TV <-> ',
#   'turn left, walk around the coffee table to the other side <-> ',
#   'grab the yellow bottle near the edge <-> ',
#   'turn left, walk around the chairs to the corner of the room  <-> ',
#   'turn on the light behind the TV <-> '],
#  ['grab the yellow bottle on the coffee table, turn on the light behind the TV <-> ',
#   'turn left, walk around the coffee table to the other side <-> ',
#   'grab the yellow bottle near the edge <-> ',
#   'turn left, walk around the chairs to the corner of the room  <-> ',
#   'turn on the light behind the TV <-> '],
#  ['grab the yellow bottle on the coffee table, turn on the light behind the TV <-> ',
#   'turn left, walk around the coffee table to the other side <-> ',
#   'grab the yellow bottle near the edge <-> ',
#   'turn left, walk around the chairs to the corner of the room  <-> ',
#   'turn on the light behind the TV <-> '],
#  ...]

# %% [markdown]
# ### Preparea data for finetuning BARTforConditionalGeneration using huggingface scripts
